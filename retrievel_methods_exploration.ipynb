# %% [markdown]
# ## File Based Search

# %%
import os, sys
from collections import defaultdict

# Configurations
freebase_dir    = "/run/media/sakhil/sakhil/IIIT H/ANLP/Project/freebase-easy-14-04-14"
facts_file      = os.path.join(freebase_dir, "facts.txt")

#to test on example
question="what does jamaican people speak?"
anchor_mention  = "Jamaican"   
predicted_hops  = 1            

# Candidate selection caps (INT or NONE)
CANDIDATE_LIMIT        = None  
MAX_NAME_LINES_SCANNED = None  

# BFS caps
MAX_FRONTIER_NODES_PER_DEPTH = 2000   
MAX_EDGES_PER_NODE_PER_DEPTH = 30       
MAX_PATHS_PER_DEPTH          = 50000  
PRINT_SAMPLE_LIMIT           = 50

# Skip noisy predicates to reduce branching (updated for Freebase-easy)
SKIP_PREDICATES_PREFIXES = {
    "Length",
    "Track #", 
    "is-a",
}

# %%
def norm_mid(mid: str) -> str:
    if mid.startswith("/m/"):
        return "m." + mid[3:]
    if mid.startswith("m/"):
        return "m." + mid[2:]
    return mid

def extract_entity_info(entity_str):
    entity_str = entity_str.strip()
    if entity_str.endswith(')') and '(m/' in entity_str:
        # Has MID: "Jamaica (m/03_r3)"
        parts = entity_str.rsplit('(m/', 1)
        if len(parts) == 2:
            name = parts[0].strip()
            mid = 'm.' + parts[1][:-1]  # remove closing paren, add dot
            return mid, name
    # No MID found, use entity string as both ID and name
    return entity_str, entity_str

def iter_facts(path, max_lines=None):
    n = 0
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        for raw in f:
            if max_lines is not None and n >= max_lines:
                break
            line = raw.strip()
            if not line or line.startswith("#"):
                continue
            parts = line.split("\t")
            if len(parts) < 3:
                parts = line.split()
            if len(parts) < 3:
                continue
            s, p, o = parts[0], parts[1], " ".join(parts[2:])
            # Remove trailing period if present
            if o.endswith('\t.'):
                o = o[:-2].strip()
            elif o.endswith('.'):
                o = o[:-1].strip()
            yield s, p, o
            n += 1

def clean_literal(obj: str) -> str:
    t = obj.strip()
    if t.startswith('"') and '"' in t[1:]:
        # remove first and last quote if balanced
        if t.endswith('"') or '"@' in t:
            t = t[1:]
            # split by last quote
            qpos = t.rfind('"')
            if qpos != -1:
                t = t[:qpos]
    # drop @lang if still present
    t = t.split('@')[0]
    return t

def fmt_path(seq): return " → ".join(seq) if seq else "(empty)"

# %%
if not os.path.exists(facts_file):
    print(f"[ERROR] facts.txt not found at: {facts_file}", file=sys.stderr)
    sys.exit(1)

mention_cf = anchor_mention.strip().casefold()
if not mention_cf:
    print("[ERROR] anchor_mention is empty.", file=sys.stderr)
    sys.exit(1)

print(f"[INFO] Searching anchor candidates for mention: '{anchor_mention}'", file=sys.stderr)

exact_hits = []   # (mid, label)
substr_hits = []  # (mid, label)
seen_entities = set()

def extract_entity_info(entity_str):
    """Extract MID and clean name from entity string like 'Jamaica (m/03_r3)' or 'Jamaica'"""
    entity_str = entity_str.strip()
    if entity_str.endswith(')') and '(m/' in entity_str:
        # Has MID: "Jamaica (m/03_r3)"
        parts = entity_str.rsplit('(m/', 1)
        if len(parts) == 2:
            name = parts[0].strip()
            mid = 'm.' + parts[1][:-1]  # remove closing paren, add dot
            return mid, name
    return entity_str, entity_str

# Search through facts for entities containing the mention
for s, p, o in iter_facts(facts_file, max_lines=MAX_NAME_LINES_SCANNED):
    # Check subject
    if mention_cf in s.casefold():
        mid, name = extract_entity_info(s)
        if mid not in seen_entities:
            if s.casefold() == mention_cf or name.casefold() == mention_cf:
                exact_hits.append((mid, name))
            else:
                substr_hits.append((mid, name))
            seen_entities.add(mid)
    
    # Check object (if it looks like an entity, not a literal)
    if not (o.startswith('"') or o.startswith('<http')) and mention_cf in o.casefold():
        mid, name = extract_entity_info(o)
        if mid not in seen_entities:
            if o.casefold() == mention_cf or name.casefold() == mention_cf:
                exact_hits.append((mid, name))
            else:
                substr_hits.append((mid, name))
            seen_entities.add(mid)

# Merge exact + substr respecting CANDIDATE_LIMIT
if CANDIDATE_LIMIT is None:
    candidates = exact_hits + substr_hits
else:
    need = CANDIDATE_LIMIT
    candidates = exact_hits[:need]
    if len(candidates) < need:
        candidates += substr_hits[:(need - len(candidates))]

if not candidates:
    print(f"[WARN] No candidates found for mention='{anchor_mention}'. "
          f"Try MAX_NAME_LINES_SCANNED=None and ensure the mention exists in your dump.", file=sys.stderr)
    sys.exit(0)

print("[INFO] Anchor candidates:")
for i, (mid, label) in enumerate(candidates, 1):
    print(f"  [{i}] {mid}   «{label}»")
# Out:
# [INFO] Searching anchor candidates for mention: 'Jamaican'
# [INFO] Anchor candidates:
#   [1] Jamaican   «Jamaican»
#   [2] m.0lp70fh   «Jamaican»
#   [3] m.0m38_m4   «Jamaican»
#   [4] m.0mbvqy_   «Jamaican»
#   [5] m.0mlgpx9   «Jamaican»
#   [6] m.0mv164s   «Jamaican»
#   [7] m.0n6kx9t   «Jamaican»
#   [8] "Assertive 'no' in Jamaican Creole" (Book Edition)   «"Assertive 'no' in Jamaican Creole" (Book Edition)»
#   [9] "Assertive 'no' in Jamaican Creole" (Book)   «"Assertive 'no' in Jamaican Creole" (Book)»
#   [10] Jamaican Barbie   «Jamaican Barbie»
#   [11] Trojan Jamaican R&B Box Set (Consumer product)   «Trojan Jamaican R&B Box Set (Consumer product)»
#   [12] Jamaican Style (Consumer product)   «Jamaican Style (Consumer product)»
#   [13] Roots Reggae: The Classic Jamaican Albums (Multi-Part Musical Release)   «Roots Reggae: The Classic Jamaican Albums (Multi-Part Musical Release)»
#   [14] Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Compact Disc Musical Release)   «Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Compact Disc Musical Release)»
#   [15] (To Be) Young, Gifted & Black (Jamaican mix) (Musical Recording)   «(To Be) Young, Gifted & Black (Jamaican mix) (Musical Recording)»
#   [16] m.0l6pwt0   «(To Be) Young, Gifted & Black (Jamaican mix)»
#   [17] Tougher Than Tough: The Story of Jamaican Music (Consumer product)   «Tougher Than Tough: The Story of Jamaican Music (Consumer product)»
#   [18] Soundsystem: The Story of Jamaican Music (Compact Disc Musical Release)   «Soundsystem: The Story of Jamaican Music (Compact Disc Musical Release)»
#   [19] Jamaican Street Legal   «Jamaican Street Legal»
#   [20] Jamaican E.T. (Consumer product) #3   «Jamaican E.T. (Consumer product) #3»
#   [21] Jamaican E.T. (Consumer product) #4   «Jamaican E.T. (Consumer product) #4»
#   [22] Love Forever: The Classic Jamaican Recordings (Compact Disc Musical Release)   «Love Forever: The Classic Jamaican Recordings (Compact Disc Musical Release)»
#   [23] Montego Bay - Jamaican Persuasion (Compact Disc Musical Release)   «Montego Bay - Jamaican Persuasion (Compact Disc Musical Release)»
#   [24] The Reggae Box: The Routes of Jamaican Music (Compact Disc Musical Release)   «The Reggae Box: The Routes of Jamaican Music (Compact Disc Musical Release)»
#   [25] The Jamaican Episode (Compact Disc Musical Release)   «The Jamaican Episode (Compact Disc Musical Release)»
#   [26] 2 Sounds (Jamaican Icetea version) (Musical Recording)   «2 Sounds (Jamaican Icetea version) (Musical Recording)»
#   [27] m.0mv6ww2   «2 Sounds (Jamaican Icetea version)»
#   [28] Arise Rootsman: Jamaican Roots 1965-1983 (Compact Disc Musical Release)   «Arise Rootsman: Jamaican Roots 1965-1983 (Compact Disc Musical Release)»
#   [29] The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)   «The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)»
#   [30] Soul Revolutionaries: The Early Jamaican Albums (Musical Release Component)   «Soul Revolutionaries: The Early Jamaican Albums (Musical Release Component)»
#   [31] Catch a Fire (disc 1: The Jamaican Versions)   «Catch a Fire (disc 1: The Jamaican Versions)»
#   [32] The Jamaican Dub Versions, Volume 2 (Compact Disc Musical Release)   «The Jamaican Dub Versions, Volume 2 (Compact Disc Musical Release)»
#   [33] 50 Years of Jamaican Music 1962 - 2012 (Compact Disc Musical Release)   «50 Years of Jamaican Music 1962 - 2012 (Compact Disc Musical Release)»
#   [34] 50 Years of Jamaican Music 1962 - 2012 (Musical Album)   «50 Years of Jamaican Music 1962 - 2012 (Musical Album)»
#   [35] Jamaican Monkey Man (Compact Disc Musical Release)   «Jamaican Monkey Man (Compact Disc Musical Release)»
#   [36] Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Compact Disc Musical Release)   «Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Compact Disc Musical Release)»
#   [37] Trojan Jamaican Hits Box Set (disc 2)   «Trojan Jamaican Hits Box Set (disc 2)»
#   [38] Trojan Jamaican Hits Box Set (Multi-Part Musical Release)   «Trojan Jamaican Hits Box Set (Multi-Part Musical Release)»
#   [39] Bloodlines - Jamaican Dub & Roots (Consumer product)   «Bloodlines - Jamaican Dub & Roots (Consumer product)»
#   [40] High Plains Drifter: Jamaican 45's 1968-73 (Consumer product)   «High Plains Drifter: Jamaican 45's 1968-73 (Consumer product)»
#   [41] A Conversation With Children / Jamaican Rumba (Musical Recording)   «A Conversation With Children / Jamaican Rumba (Musical Recording)»
#   [42] m.0lzwbvr   «A Conversation With Children / Jamaican Rumba»
#   [43] m.0ms8ld4   «A Conversation With Children / Jamaican Rumba»
#   [44] Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #2   «Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #2»
#   [45] Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #1   «Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #1»
#   [46] A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Album)   «A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Album)»
#   [47] A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Release)   «A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Release)»
#   [48] A Jamaican Collection (Compact Disc Musical Release)   «A Jamaican Collection (Compact Disc Musical Release)»
#   [49] A Jamaican Collection (Musical Album)   «A Jamaican Collection (Musical Album)»
#   [50] A Jamaican in New York (Musical Recording) #1   «A Jamaican in New York (Musical Recording) #1»
#   [51] Jamaican In New York (Musical Recording) #1   «Jamaican In New York (Musical Recording) #1»
#   [52] A Jamaican in New York (Musical Recording) #2   «A Jamaican in New York (Musical Recording) #2»
#   [53] A Jamaican in New York (Musical Recording) #3   «A Jamaican in New York (Musical Recording) #3»
#   [54] m.0ljj22k   «A Jamaican in New York»
#   [55] m.0lmckm2   «A Jamaican in New York»
#   [56] m.0m6cv2l   «A Jamaican in New York»
#   [57] m.0n2_17z   «A Jamaican in New York»
#   [58] A Jamaican plantation   «A Jamaican plantation»
#   [59] A Jamaican plantation: the history of Worthy Park 1670-1970   «A Jamaican plantation: the history of Worthy Park 1670-1970»
#   [60] A Jamaican storyteller's tale (Book Edition)   «A Jamaican storyteller's tale (Book Edition)»
#   [61] A Jamaican storyteller's tale (Book)   «A Jamaican storyteller's tale (Book)»
#   [62] The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)   «The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)»
#   [63] The Jamaican Beat (Musical Release)   «The Jamaican Beat (Musical Release)»
#   [64] Jamaican Funk—Canadian Style (Consumer product)   «Jamaican Funk—Canadian Style (Consumer product)»
#   [65] A boy named Ossie : a Jamaican childhood   «A boy named Ossie : a Jamaican childhood»
#   [66] A man divided: Michael Garfield Smith : Jamaican poet and anthropologist, 1921-1993   «A man divided: Michael Garfield Smith : Jamaican poet and anthropologist, 1921-1993»
#   [67] A reanalysis of the phonological system of Jamaican Creole (Book Edition)   «A reanalysis of the phonological system of Jamaican Creole (Book Edition)»
#   [68] A reanalysis of the phonological system of Jamaican Creole (Book)   «A reanalysis of the phonological system of Jamaican Creole (Book)»
#   [69] A-Z of Jamaican heritage   «A-Z of Jamaican heritage»
#   [70] The Classic Jamaican Recordings Finest Vocal Trio (Musical Release)   «The Classic Jamaican Recordings Finest Vocal Trio (Musical Release)»
#   [71] Original Cool Jamaican Ska (Compact Disc Musical Release)   «Original Cool Jamaican Ska (Compact Disc Musical Release)»
#   [72] The Long Hot Summer: Jamaican Ska 1963 (Compact Cassette Musical Release)   «The Long Hot Summer: Jamaican Ska 1963 (Compact Cassette Musical Release)»
#   [73] Adult and non-formal education in the Third World : a Jamaican perspective   «Adult and non-formal education in the Third World : a Jamaican perspective»
#   [74] Jamaican Roots (Consumer product)   «Jamaican Roots (Consumer product)»
#   [75] African Jamaican (Musical Recording)   «African Jamaican (Musical Recording)»
#   [76] m.0ln7ykk   «African Jamaican»
#   [77] African retentions in Jamaican Creole   «African retentions in Jamaican Creole»
#   [78] African retentions in Jamaican Creole : a reassessment   «African retentions in Jamaican Creole : a reassessment»
#   [79] Trojan Box Set: Jamaican Superstars (disc 3)   «Trojan Box Set: Jamaican Superstars (disc 3)»
#   [80] Trojan Jamaican Superstars Box Set (Multi-Part Musical Release)   «Trojan Jamaican Superstars Box Set (Multi-Part Musical Release)»
#   [81] Dancehall: The Rise of Jamaican Dancehall Culture (Compact Disc Musical Release)   «Dancehall: The Rise of Jamaican Dancehall Culture (Compact Disc Musical Release)»
#   [82] Reggae Love Songs: 50 Jamaican Lovers Classics (Compact Disc Musical Release)   «Reggae Love Songs: 50 Jamaican Lovers Classics (Compact Disc Musical Release)»
#   [83] Aintcha Gonna Be a Jamaican (Canonical Version)   «Aintcha Gonna Be a Jamaican (Canonical Version)»
#   [84] m.0l86pdc   «Aintcha Gonna Be a Jamaican»
#   [85] The Pioneer of Jamaican Music (Compact Disc Musical Release)   «The Pioneer of Jamaican Music (Compact Disc Musical Release)»
#   [86] The Pioneer of Jamaican Music (Consumer product)   «The Pioneer of Jamaican Music (Consumer product)»
#   [87] The Pioneer of Jamaican Music (Gramophone record Musical Release)   «The Pioneer of Jamaican Music (Gramophone record Musical Release)»
#   [88] Jamaican American   «Jamaican American»
#   [89] Albert's Real Jamaican Foods   «Albert's Real Jamaican Foods»
#   [90] American Guestworkers: Jamaicans And Mexicans in the U.S. Labor Market (Rural Studies)   «American Guestworkers: Jamaicans And Mexicans in the U.S. Labor Market (Rural Studies)»
#   [91] An eclectic approach to estimating the determinants of achievement in Jamaican primary education   «An eclectic approach to estimating the determinants of achievement in Jamaican primary education»
#   [92] Anansi, the spider man; Jamaican folk tales   «Anansi, the spider man; Jamaican folk tales»
#   [93] Jamaicans of African ancestry   «Jamaicans of African ancestry»
#   [94] Hot Jamaican Mixture (Compact Disc Musical Release)   «Hot Jamaican Mixture (Compact Disc Musical Release)»
#   [95] Arise Rootsman: Jamaican Roots 1965-1983 (Musical Album)   «Arise Rootsman: Jamaican Roots 1965-1983 (Musical Album)»
#   [96] Arise ye starvelings: the Jamaican labour rebellion of 1938 and its aftermath   «Arise ye starvelings: the Jamaican labour rebellion of 1938 and its aftermath»
#   [97] Jamaican Queens   «Jamaican Queens»
#   [98] Jamaican Style (Compact Disc Musical Release)   «Jamaican Style (Compact Disc Musical Release)»
#   [99] Katani's Jamaican Holiday   «Katani's Jamaican Holiday»
#   [100] Roots & Urban Culture: Una muestra del legado jamaicano (Musical Release)   «Roots & Urban Culture: Una muestra del legado jamaicano (Musical Release)»
#   [101] The Jamaicans   «The Jamaicans»
#   [102] Trojan: Classic Jamaican Sounds Since 1968 (Compact Disc Musical Release)   «Trojan: Classic Jamaican Sounds Since 1968 (Compact Disc Musical Release)»
#   [103] Jamaican Beat (Consumer product)   «Jamaican Beat (Consumer product)»
#   [104] Work Your Soul: Jamaican 60s & Northern 1966-74 (Consumer product)   «Work Your Soul: Jamaican 60s & Northern 1966-74 (Consumer product)»
#   [105] Trojan Box Set: Jamaican Superstars (disc 1)   «Trojan Box Set: Jamaican Superstars (disc 1)»
#   [106] Baby I'm a Want You (Jamaican mix) (Musical Recording)   «Baby I'm a Want You (Jamaican mix) (Musical Recording)»
#   [107] m.0ly3sc5   «Baby I'm a Want You (Jamaican mix)»
#   [108] Bactris jamaicana   «Bactris jamaicana»
#   [109] Run Tings (100% Jamaican dub plates) (Consumer product)   «Run Tings (100% Jamaican dub plates) (Consumer product)»
#   [110] Jamaican Recordings (Consumer product)   «Jamaican Recordings (Consumer product)»
#   [111] Bad Weed (extended Jamaican mix)   «Bad Weed (extended Jamaican mix)»
#   [112] Disco Devil: The Jamaican Disco Mixes (Consumer product)   «Disco Devil: The Jamaican Disco Mixes (Consumer product)»
#   [113] Jamaican food   «Jamaican food»
#   [114] Dancehall 2: The Rise of Jamaican Dancehall Culture (Consumer product)   «Dancehall 2: The Rise of Jamaican Dancehall Culture (Consumer product)»
#   [115] Jamaican fruit bat   «Jamaican fruit bat»
#   [116] Trojan Jamaican Hits Box Set (disc 1)   «Trojan Jamaican Hits Box Set (disc 1)»
#   [117] Trojan Jamaican Hits Box Set (disc 3)   «Trojan Jamaican Hits Box Set (disc 3)»
#   [118] Bedasse & The Jamaican Calypsonians   «Bedasse & The Jamaican Calypsonians»
#   [119] Jamaican Gold (Music Film)   «Jamaican Gold (Music Film)»
#   [120] Rude Boy: The Jamaican Don   «Rude Boy: The Jamaican Don»
#   [121] Believing identity : Pentecostalism and the mediation of Jamaican ethnicity and gender in England   «Believing identity : Pentecostalism and the mediation of Jamaican ethnicity and gender in England»
#   [122] Ben Bowers & Bertie King's Royal Jamaicans   «Ben Bowers & Bertie King's Royal Jamaicans»
#   [123] Bend Down Low (alternate Jamaican Soul mix) (Musical Recording)   «Bend Down Low (alternate Jamaican Soul mix) (Musical Recording)»
#   [124] m.0ly8v8g   «Bend Down Low (alternate Jamaican Soul mix)»
#   [125] Trojan Box Set: Jamaican Superstars (disc 2)   «Trojan Box Set: Jamaican Superstars (disc 2)»
#   [126] Bibliography of Jamaican geology (Book Edition)   «Bibliography of Jamaican geology (Book Edition)»
#   [127] Bibliography of Jamaican geology (Book)   «Bibliography of Jamaican geology (Book)»
#   [128] Boogu Yagga Gal: Jamaican Mento (Musical Release)   «Boogu Yagga Gal: Jamaican Mento (Musical Release)»
#   [129] Biologica Robotica (Jamaican Cyberturtle) (Canonical Version)   «Biologica Robotica (Jamaican Cyberturtle) (Canonical Version)»
#   [130] m.0nqmql5   «Biologica Robotica (Jamaican Cyberturtle)»
#   [131] Black Jamaicans' struggle against slavery   «Black Jamaicans' struggle against slavery»
#   [132] Bloodlines - Jamaican Dub & Roots (Musical Album)   «Bloodlines - Jamaican Dub & Roots (Musical Album)»
#   [133] Jamaican Order of Merit   «Jamaican Order of Merit»
#   [134] Bob Marley & Toots Cover in Jamaican Ganja Field (Canonical Version)   «Bob Marley & Toots Cover in Jamaican Ganja Field (Canonical Version)»
#   [135] m.0yc37zw   «Bob Marley & Toots Cover in Jamaican Ganja Field»
#   [136] Carlos Malcolm & His Afro-Jamaican Rhythms   «Carlos Malcolm & His Afro-Jamaican Rhythms»
#   [137] Easy Snapping: The Jamaican Chart Hits of 1960 (Consumer product)   «Easy Snapping: The Jamaican Chart Hits of 1960 (Consumer product)»
#   [138] Boogu Yagga Gal: Jamaican Mento (Musical Album)   «Boogu Yagga Gal: Jamaican Mento (Musical Album)»
#   [139] Jamaican Creole English Language   «Jamaican Creole English Language»
#   [140] Born Jamaican (Musical Recording)   «Born Jamaican (Musical Recording)»
#   [141] m.0l18017   «Born Jamaican»
#   [142] Born Jamaicans   «Born Jamaicans»
#   [143] Born fi' dead: a journey through the Jamaican posse underworld   «Born fi' dead: a journey through the Jamaican posse underworld»
#   [144] British Jamaican   «British Jamaican»
#   [145] Jamaican English   «Jamaican English»
#   [146] Jamaica Funk - Original Jamaican Funk and Soul 45's (Consumer product)   «Jamaica Funk - Original Jamaican Funk and Soul 45's (Consumer product)»
#   [147] Busha Browne's indispensable compendium of traditional Jamaican cookery (Book Edition)   «Busha Browne's indispensable compendium of traditional Jamaican cookery (Book Edition)»
#   [148] Busha Browne's indispensable compendium of traditional Jamaican cookery (Book)   «Busha Browne's indispensable compendium of traditional Jamaican cookery (Book)»
#   [149] Jamaican folk music   «Jamaican folk music»
#   [150] Canadianizing Jamaican patois   «Canadianizing Jamaican patois»
#   [151] Carl Stone on Jamaican politics, economics & society   «Carl Stone on Jamaican politics, economics & society»
#   [152] Jamaicans for Justice   «Jamaicans for Justice»
#   [153] Chances Are (alternate Jamaican Soul mix) (Musical Recording)   «Chances Are (alternate Jamaican Soul mix) (Musical Recording)»
#   [154] m.0ly8v64   «Chances Are (alternate Jamaican Soul mix)»
#   [155] Jamaicanization (Consumer product)   «Jamaicanization (Consumer product)»
#   [156] Chinese Jamaicans   «Chinese Jamaicans»
#   [157] Classic Jamaican Cooking   «Classic Jamaican Cooking»
#   [158] Codeswitching on the web : English and Jamaican Creole in e-mail communication   «Codeswitching on the web : English and Jamaican Creole in e-mail communication»
#   [159] The General Da Jamaican Boy   «The General Da Jamaican Boy»
#   [160] m.0rs6vlc   «Come Along/Jamaican Collie (extended mix)»
#   [161] m.0rtt7yj   «Come Along/Jamaican Collie (extended mix)»
#   [162] Jamaica: Anthology of Jamaican Music (Musical Release)   «Jamaica: Anthology of Jamaican Music (Musical Release)»
#   [163] Creole languages of the Caribbean Area : a comparison of the grammar of Jamaican Creole with those of the Creole languages of Haiti, the Antilles, the Guianas, the Virgin Islands, and the Dutch West Indies   «Creole languages of the Caribbean Area : a comparison of the grammar of Jamaican Creole with those of the Creole languages of Haiti, the Antilles, the Guianas, the Virgin Islands, and the Dutch West Indies»
#   [164] Dancehall 2: The Rise of Jamaican Dancehall Culture (Musical Album)   «Dancehall 2: The Rise of Jamaican Dancehall Culture (Musical Album)»
#   [165] Dancehall: The Rise of Jamaican Dancehall Culture (Musical Album)   «Dancehall: The Rise of Jamaican Dancehall Culture (Musical Album)»
#   [166] Jamaican Celebration (Compact Disc Musical Release)   «Jamaican Celebration (Compact Disc Musical Release)»
#   [167] Jamaican Heroes (Musical Release)   «Jamaican Heroes (Musical Release)»
#   [168] Defining Jamaican fiction   «Defining Jamaican fiction»
#   [169] Defining Jamaican fiction : marronage and the discourse of survival   «Defining Jamaican fiction : marronage and the discourse of survival»
#   [170] Democratic socialism and the capitalist class : an analysis of the relation between Jamaican business and the PNP government   «Democratic socialism and the capitalist class : an analysis of the relation between Jamaican business and the PNP government»
#   [171] Diplomats- Jamaican Joint (Canonical Version)   «Diplomats- Jamaican Joint (Canonical Version)»
#   [172] m.0lg0qnz   «Diplomats- Jamaican Joint»
#   [173] Disco Devil: The Jamaican Disco Mixes (Musical Album)   «Disco Devil: The Jamaican Disco Mixes (Musical Album)»
#   [174] Distinguished Jamaican English (Musical Recording)   «Distinguished Jamaican English (Musical Recording)»
#   [175] Distinguished Jamaican English (The Herbaliser Remix Instrumental) (Musical Recording)   «Distinguished Jamaican English (The Herbaliser Remix Instrumental) (Musical Recording)»
#   [176] m.0smhm7j   «Distinguished Jamaican English (The Herbaliser Remix Instrumental)»
#   [177] Distinguished Jamaican English (The Herbaliser remix instrumental) (Musical Recording)   «Distinguished Jamaican English (The Herbaliser remix instrumental) (Musical Recording)»
#   [178] Time to Build / Distinguished Jamaican English   «Time to Build / Distinguished Jamaican English»
#   [179] m.0n10zny   «Distinguished Jamaican English (The Herbaliser remix instrumental)»
#   [180] Distinguished Jamaican English (The Herbaliser remix)   «Distinguished Jamaican English (The Herbaliser remix)»
#   [181] Distinguished Jamaican English (The Herbaliser remix) (feat. Phi-Life Cypher)   «Distinguished Jamaican English (The Herbaliser remix) (feat. Phi-Life Cypher)»
#   [182] Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix) (Musical Recording)   «Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix) (Musical Recording)»
#   [183] m.0skp6mv   «Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix)»
#   [184] Distinguished Jamaican English (feat. Phi-Life Cypher) (Musical Recording)   «Distinguished Jamaican English (feat. Phi-Life Cypher) (Musical Recording)»
#   [185] m.0q9rf_9   «Distinguished Jamaican English (feat. Phi-Life Cypher)»
#   [186] m.0lsyw5q   «Distinguished Jamaican English»
#   [187] Distinguished Jamaican English Remix (Instrumental) (Musical Recording)   «Distinguished Jamaican English Remix (Instrumental) (Musical Recording)»
#   [188] Distinguished Jamaican English Remix (feat. Phi Life Cypher) (Canonical Version)   «Distinguished Jamaican English Remix (feat. Phi Life Cypher) (Canonical Version)»
#   [189] m.0l6dxbz   «Distinguished Jamaican English Remix (Instrumental)»
#   [190] m.0l6dxbq   «Distinguished Jamaican English Remix (feat. Phi Life Cypher)»
#   [191] Jamaican Rock Steady Party (Compact Disc Musical Release)   «Jamaican Rock Steady Party (Compact Disc Musical Release)»
#   [192] Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN) (Musical Recording)   «Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN) (Musical Recording)»
#   [193] m.0m9p0yw   «Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN)»
#   [194] Don't Stop the Music (Smooth Jamaican mix) (Musical Recording)   «Don't Stop the Music (Smooth Jamaican mix) (Musical Recording)»
#   [195] m.0mj_0mz   «Don't Stop the Music (Smooth Jamaican mix)»
#   [196] The Jamaican Calypsonians   «The Jamaican Calypsonians»
#   [197] Jamaican Guys   «Jamaican Guys»
#   [198] Drumblair: Memories of a Jamaican Childhood   «Drumblair: Memories of a Jamaican Childhood»
#   [199] Jamaican Recordings (Record label)   «Jamaican Recordings (Record label)»
#   [200] Easy Snapping: The Jamaican Chart Hits of 1960 (Musical Album)   «Easy Snapping: The Jamaican Chart Hits of 1960 (Musical Album)»
#   [201] En Aquel Hotel Jamaicano (Musical Recording)   «En Aquel Hotel Jamaicano (Musical Recording)»
#   [202] m.0kzqvxp   «En Aquel Hotel Jamaicano»
#   [203] m.0mgkk6r   «En Aquel Hotel Jamaicano»
#   [204] Encyclopedia of Jamaican heritage   «Encyclopedia of Jamaican heritage»
#   [205] Encyclopedia of Jamaican heritage (Book Edition)   «Encyclopedia of Jamaican heritage (Book Edition)»
#   [206] Envisioning Caribbean futures : Jamaican perspectives   «Envisioning Caribbean futures : Jamaican perspectives»
#   [207] Episode 6: Jamaican   «Episode 6: Jamaican»
#   [208] Mr. T-Bone and his Jamaican Liberation Orchestra   «Mr. T-Bone and his Jamaican Liberation Orchestra»
#   [209] Fakin' Jamaican (Musical Recording) #1   «Fakin' Jamaican (Musical Recording) #1»
#   [210] Fakin' Jamaican (Musical Recording) #3   «Fakin' Jamaican (Musical Recording) #3»
#   [211] Fakin' Jamaican (Musical Recording) #2   «Fakin' Jamaican (Musical Recording) #2»
#   [212] m.0kn5xvs   «Fakin' Jamaican»
#   [213] m.0ktp5k_   «Fakin' Jamaican»
#   [214] m.0n85qvf   «Fakin' Jamaican»
#   [215] Fire Water Burn (Jim Makin' Jamaican mix) (Musical Recording)   «Fire Water Burn (Jim Makin' Jamaican mix) (Musical Recording)»
#   [216] m.0zvsgxn   «Fire Water Burn (Jim Makin' Jamaican mix)»
#   [217] Fire Water Burn (Jim Makin’ Jamaican Mix)   «Fire Water Burn (Jim Makin’ Jamaican Mix)»
#   [218] m.0khzfvc   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [219] m.0kmrql8   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [220] m.0mc1_lf   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [221] m.0mszkxx   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [222] m.0mvhp32   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [223] m.0rv31k7   «Fire Water Burn (Jim Makin’ Jamaican mix)»
#   [224] Jamaican Amber Rum   «Jamaican Amber Rum»
#   [225] Jamaican-Inspired Bedroom   «Jamaican-Inspired Bedroom»
#   [226] Folklore from contemporary Jamaicans (Book Edition)   «Folklore from contemporary Jamaicans (Book Edition)»
#   [227] Folklore from contemporary Jamaicans (Book)   «Folklore from contemporary Jamaicans (Book)»
#   [228] Girl From Ipanema (Jamaican mix) (Musical Recording)   «Girl From Ipanema (Jamaican mix) (Musical Recording)»
#   [229] m.0ly3s7v   «Girl From Ipanema (Jamaican mix)»
#   [230] Growing Up Jamaican   «Growing Up Jamaican»
#   [231] Help Me Make It Through the Night (Jamaican mix) (Musical Recording)   «Help Me Make It Through the Night (Jamaican mix) (Musical Recording)»
#   [232] m.0ly3scm   «Help Me Make It Through the Night (Jamaican mix)»
#   [233] High Plains Drifter: Jamaican 45's 1968-73 (Musical Album)   «High Plains Drifter: Jamaican 45's 1968-73 (Musical Album)»
#   [234] High School / Jamaican Boa (Musical Recording)   «High School / Jamaican Boa (Musical Recording)»
#   [235] High School / Jamaican Boa (interlude) (Musical Recording)   «High School / Jamaican Boa (interlude) (Musical Recording)»
#   [236] m.0mqjxgz   «High School / Jamaican Boa (interlude)»
#   [237] m.0msxg7b   «High School / Jamaican Boa (interlude)»
#   [238] m.0rrrb3m   «High School / Jamaican Boa»
#   [239] Jamaican iguana   «Jamaican iguana»
#   [240] Hot Jamaican Mixture (Musical Album)   «Hot Jamaican Mixture (Musical Album)»
#   [241] Hot Jamaican Mixture (Musical Release)   «Hot Jamaican Mixture (Musical Release)»
#   [242] How to speak Jamaican? (Book Edition)   «How to speak Jamaican? (Book Edition)»
#   [243] How to speak Jamaican? (Book)   «How to speak Jamaican? (Book)»
#   [244] Ska Boogie: Jamaican R&B, the Dawn of Ska (Compact Disc Musical Release)   «Ska Boogie: Jamaican R&B, the Dawn of Ska (Compact Disc Musical Release)»
#   [245] I Love The Piano / Jamaican Style (Gramophone record Musical Release)   «I Love The Piano / Jamaican Style (Gramophone record Musical Release)»
#   [246] I Love The Piano / Jamaican Style (Musical Album)   «I Love The Piano / Jamaican Style (Musical Album)»
#   [247] Ilex jamaicana   «Ilex jamaicana»
#   [248] Irie Jamaican Girl (Canonical Version)   «Irie Jamaican Girl (Canonical Version)»
#   [249] m.0nr6l2j   «Irie Jamaican Girl»
#   [250] JAMAICAN TEAS LTD Common Stock   «JAMAICAN TEAS LTD Common Stock»
#   [251] Jamaican Teas   «Jamaican Teas»
#   [252] JAMAICAN WARRIORS: REGGAE, ROOTS & CULTURE   «JAMAICAN WARRIORS: REGGAE, ROOTS & CULTURE»
#   [253] Jamaican Warriors   «Jamaican Warriors»
#   [254] Jah music: the evolution of the popular Jamaican song   «Jah music: the evolution of the popular Jamaican song»
#   [255] Jamaican dollar   «Jamaican dollar»
#   [256] Jamaica (Jamaican Getaway)   «Jamaica (Jamaican Getaway)»
#   [257] Jamaican Farewell (Musical Recording) #5   «Jamaican Farewell (Musical Recording) #5»
#   [258] Jamaica Funk - Original Jamaican Funk and Soul 45's (Musical Album)   «Jamaica Funk - Original Jamaican Funk and Soul 45's (Musical Album)»
#   [259] Jamaica farewell: Jamaican migrants in London   «Jamaica farewell: Jamaican migrants in London»
#   [260] Jamaican Heroes (Musical Recording) #2   «Jamaican Heroes (Musical Recording) #2»
#   [261] Jamaica: Anthology of Jamaican Music (Musical Album)   «Jamaica: Anthology of Jamaican Music (Musical Album)»
#   [262] Jamaican (Musical Recording) #1   «Jamaican (Musical Recording) #1»
#   [263] Jamaican (Musical Recording) #2   «Jamaican (Musical Recording) #2»
#   [264] Jamaican (Musical Recording) #3   «Jamaican (Musical Recording) #3»
#   [265] Jamaican (Punk Reggae Party) (Canonical Version)   «Jamaican (Punk Reggae Party) (Canonical Version)»
#   [266] m.0kkh6vs   «Jamaican (Punk Reggae Party)»
#   [267] Jamaican (TV Episode) #4   «Jamaican (TV Episode) #4»
#   [268] Jamaican (TV Episode) #5   «Jamaican (TV Episode) #5»
#   [269] Jamaican Australian   «Jamaican Australian»
#   [270] Jamaican Bacon Experience   «Jamaican Bacon Experience»
#   [271] Jamaican Badboy (Canonical Version)   «Jamaican Badboy (Canonical Version)»
#   [272] m.0nsglc7   «Jamaican Badboy»
#   [273] Jamaican Baion (Canonical Version)   «Jamaican Baion (Canonical Version)»
#   [274] m.0n17hm7   «Jamaican Baion»
#   [275] Jamaican Barbeque (Canonical Version)   «Jamaican Barbeque (Canonical Version)»
#   [276] m.0xhj4nc   «Jamaican Barbeque»
#   [277] Jamaican Beat (Musical Album)   «Jamaican Beat (Musical Album)»
#   [278] Jamaican Becard   «Jamaican Becard»
#   [279] Jamaican Blackbird   «Jamaican Blackbird»
#   [280] Jamaican Blowhole (Musical Recording)   «Jamaican Blowhole (Musical Recording)»
#   [281] m.0my26l_   «Jamaican Blowhole»
#   [282] Jamaican Bobsledding Chant   «Jamaican Bobsledding Chant»
#   [283] m.0ktn__k   «Jamaican Bobsledding Chant»
#   [284] m.0l0nnxx   «Jamaican Bobsledding Chant»
#   [285] m.0mpwwfn   «Jamaican Bobsledding Chant»
#   [286] Jamaican Bobsleigh Federation   «Jamaican Bobsleigh Federation»
#   [287] Jamaican Born and Bred (Musical Recording)   «Jamaican Born and Bred (Musical Recording)»
#   [288] m.0mdch7r   «Jamaican Born and Bred»
#   [289] Jamaican Boy (Musical Recording) #1   «Jamaican Boy (Musical Recording) #1»
#   [290] Jamaican Boy (Musical Recording) #2   «Jamaican Boy (Musical Recording) #2»
#   [291] Jamaican Boy (Musical Recording) #3   «Jamaican Boy (Musical Recording) #3»
#   [292] Jamaican Boy (Musical Recording) #4   «Jamaican Boy (Musical Recording) #4»
#   [293] Jamaican Boy (Musical Recording) #5   «Jamaican Boy (Musical Recording) #5»
#   [294] Jamaican Boy (Musical Recording) #6   «Jamaican Boy (Musical Recording) #6»
#   [295] m.0ldch5l   «Jamaican Boy»
#   [296] m.0m1td9n   «Jamaican Boy»
#   [297] m.0m1tjmc   «Jamaican Boy»
#   [298] m.0m85q6g   «Jamaican Boy»
#   [299] m.0mjtq04   «Jamaican Boy»
#   [300] m.0myvxqp   «Jamaican Boy»
#   [301] Jamaican Breeze (Musical Recording)   «Jamaican Breeze (Musical Recording)»
#   [302] m.0lyj7xn   «Jamaican Breeze»
#   [303] Jamaican Bye-Bye (Canonical Version)   «Jamaican Bye-Bye (Canonical Version)»
#   [304] m.0qg8p9v   «Jamaican Bye-Bye»
#   [305] Jamaican Calley (Version)   «Jamaican Calley (Version)»
#   [306] Jamaican Calley (version)   «Jamaican Calley (version)»
#   [307] Jamaican Colley (version) (Musical Recording) #1   «Jamaican Colley (version) (Musical Recording) #1»
#   [308] Jamaican Callie (version) (Musical Recording)   «Jamaican Callie (version) (Musical Recording)»
#   [309] m.0kt_gq5   «Jamaican Callie (version)»
#   [310] m.0lc_gfk   «Jamaican Callie (version)»
#   [311] Jamaican Canadian   «Jamaican Canadian»
#   [312] Jamaican Caracara   «Jamaican Caracara»
#   [313] Jamaican Carnival (Musical Recording)   «Jamaican Carnival (Musical Recording)»
#   [314] m.0lzdnnj   «Jamaican Carnival»
#   [315] Jamaican Carnival, Part 1 (Canonical Version)   «Jamaican Carnival, Part 1 (Canonical Version)»
#   [316] m.0yc_vr5   «Jamaican Carnival, Part 1»
#   [317] Jamaican Carnival, Part 2 (Canonical Version)   «Jamaican Carnival, Part 2 (Canonical Version)»
#   [318] m.0ybpy5q   «Jamaican Carnival, Part 2»
#   [319] Jamaican Caves Organisation   «Jamaican Caves Organisation»
#   [320] Jamaican Celebration (Canonical Version)   «Jamaican Celebration (Canonical Version)»
#   [321] Jamaican Celebration (Musical Album)   «Jamaican Celebration (Musical Album)»
#   [322] m.0mxpv30   «Jamaican Celebration»
#   [323] Jamaican Child (Musical Recording) #1   «Jamaican Child (Musical Recording) #1»
#   [324] Jamaican Child (Musical Recording) #2   «Jamaican Child (Musical Recording) #2»
#   [325] m.0ly05q2   «Jamaican Child»
#   [326] m.0md3m94   «Jamaican Child»
#   [327] Jamaican Childhood (Musical Recording)   «Jamaican Childhood (Musical Recording)»
#   [328] m.0l7j_n2   «Jamaican Childhood»
#   [329] Jamaican Clinic (Canonical Version)   «Jamaican Clinic (Canonical Version)»
#   [330] m.0zr8dfc   «Jamaican Clinic»
#   [331] Jamaican Coffee Farmer   «Jamaican Coffee Farmer»
#   [332] Jamaican Colley (Musical Recording)   «Jamaican Colley (Musical Recording)»
#   [333] Jamaican Colley (Version) (Musical Recording)   «Jamaican Colley (Version) (Musical Recording)»
#   [334] m.0m51jr5   «Jamaican Colley (Version)»
#   [335] m.0ydbry5   «Jamaican Colley»
#   [336] Jamaican Colley (version) (Musical Recording) #2   «Jamaican Colley (version) (Musical Recording) #2»
#   [337] m.0l5bgvs   «Jamaican Colley (version)»
#   [338] m.0l7np6b   «Jamaican Colley (version)»
#   [339] m.0m56mw_   «Jamaican Colley (version)»
#   [340] Jamaican Colley Version (Musical Recording) #1   «Jamaican Colley Version (Musical Recording) #1»
#   [341] Jamaican Colley Version (Musical Recording) #2   «Jamaican Colley Version (Musical Recording) #2»
#   [342] m.0mh9173   «Jamaican Colley Version»
#   [343] m.0mmp3zs   «Jamaican Colley Version»
#   [344] Jamaican Collie (Musical Recording) #1   «Jamaican Collie (Musical Recording) #1»
#   [345] Jamaican Collie (Musical Recording) #2   «Jamaican Collie (Musical Recording) #2»
#   [346] Jamaican Collie (Musical Recording) #3   «Jamaican Collie (Musical Recording) #3»
#   [347] Jamaican Collie (Musical Recording) #4   «Jamaican Collie (Musical Recording) #4»
#   [348] Jamaican Collie (Musical Recording) #5   «Jamaican Collie (Musical Recording) #5»
#   [349] m.0lvsyf7   «Jamaican Collie»
#   [350] m.0lyr7sl   «Jamaican Collie»
#   [351] m.0lyvdj7   «Jamaican Collie»
#   [352] m.0mlk6xt   «Jamaican Collie»
#   [353] m.0mm86qc   «Jamaican Collie»
#   [354] m.0rt4lt3   «Jamaican Collie»
#   [355] Jamaican Country Sign Language   «Jamaican Country Sign Language»
#   [356] Jamaican Creole   «Jamaican Creole»
#   [357] Jamaican Creole an historical introduction to Jamaican Creole   «Jamaican Creole an historical introduction to Jamaican Creole»
#   [358] Jamaican Crow   «Jamaican Crow»
#   [359] Jamaican Cyberturtle (Canonical Version)   «Jamaican Cyberturtle (Canonical Version)»
#   [360] m.0nqmpqx   «Jamaican Cyberturtle»
#   [361] m.0nsrt7j   «Jamaican Cyberturtle»
#   [362] Jamaican Dance Mania (Musical Recording)   «Jamaican Dance Mania (Musical Recording)»
#   [363] m.0myzcxq   «Jamaican Dance Mania»
#   [364] Jamaican Day Dream (Canonical Version)   «Jamaican Day Dream (Canonical Version)»
#   [365] m.0x1bssp   «Jamaican Day Dream»
#   [366] Jamaican Diplomocracy (Canonical Version)   «Jamaican Diplomocracy (Canonical Version)»
#   [367] m.0llbkxs   «Jamaican Diplomocracy»
#   [368] Jamaican Dollar (Canonical Version)   «Jamaican Dollar (Canonical Version)»
#   [369] Jamaican Dollar (Musical Recording)   «Jamaican Dollar (Musical Recording)»
#   [370] m.0nt5vnt   «Jamaican Dollar»
#   [371] m.0w0jppl   «Jamaican Dollar»
#   [372] Jamaican Dollars (Musical Recording)   «Jamaican Dollars (Musical Recording)»
#   [373] m.0lgx7yt   «Jamaican Dollars»
#   [374] Jamaican Dream (Canonical Version)   «Jamaican Dream (Canonical Version)»
#   [375] m.0lxdd4f   «Jamaican Dream»
#   [376] Jamaican Drums (Musical Recording)   «Jamaican Drums (Musical Recording)»
#   [377] m.0m6fd6g   «Jamaican Drums»
#   [378] Jamaican Dub   «Jamaican Dub»
#   [379] Jamaican Dub (Musical Recording) #1   «Jamaican Dub (Musical Recording) #1»
#   [380] m.0kz0vr7   «Jamaican Dub»
#   [381] m.0lw343l   «Jamaican Dub»
#   [382] Jamaican Dub Style (Musical Recording)   «Jamaican Dub Style (Musical Recording)»
#   [383] m.0myzcxh   «Jamaican Dub Style»
#   [384] Jamaican Dust (Musical Recording)   «Jamaican Dust (Musical Recording)»
#   [385] m.0mb83yy   «Jamaican Dust»
#   [386] Jamaican E.T.   «Jamaican E.T.»
#   [387] Jamaican E.T. (Musical Recording) #1   «Jamaican E.T. (Musical Recording) #1»
#   [388] Jamaican E.T. (Musical Recording) #2   «Jamaican E.T. (Musical Recording) #2»
#   [389] Jamaican E.T. (Musical Release)   «Jamaican E.T. (Musical Release)»
#   [390] m.0l82tv8   «Jamaican E.T.»
#   [391] m.0mzx97z   «Jamaican E.T.»
#   [392] m.0n09rs2   «Jamaican E.T.»
#   [393] Jamaican Elaenia   «Jamaican Elaenia»
#   [394] Jamaican Euphonia   «Jamaican Euphonia»
#   [395] Jamaican Farewell   «Jamaican Farewell»
#   [396] Jamaican Farewell (Canonical Version) #1   «Jamaican Farewell (Canonical Version) #1»
#   [397] Jamaican Farewell (Canonical Version) #3   «Jamaican Farewell (Canonical Version) #3»
#   [398] Jamaican Farewell (Musical Recording) #2   «Jamaican Farewell (Musical Recording) #2»
#   [399] Jamaican Farewell (Musical Recording) #4   «Jamaican Farewell (Musical Recording) #4»
#   [400] m.0lws6c5   «Jamaican Farewell»
#   [401] m.0m3x4p6   «Jamaican Farewell»
#   [402] m.0mvqj85   «Jamaican Farewell»
#   [403] m.0mz55jc   «Jamaican Farewell»
#   [404] m.0n0ll33   «Jamaican Farewell»
#   [405] m.0y8y_jy   «Jamaican Farewell»
#   [406] Jamaican Funk (Canonical Version)   «Jamaican Funk (Canonical Version)»
#   [407] m.0_j1ph4   «Jamaican Funk»
#   [408] Jamaican Funk—Canadian Style   «Jamaican Funk—Canadian Style»
#   [409] Jamaican Funk—Canadian Style (Canonical Version)   «Jamaican Funk—Canadian Style (Canonical Version)»
#   [410] m.0_jrqh4   «Jamaican Funk—Canadian Style»
#   [411] Jamaican Gangs, Guns and Ganja (TV Episode) #1   «Jamaican Gangs, Guns and Ganja (TV Episode) #1»
#   [412] Jamaican Gangs, Guns and Ganja (TV Episode) #2   «Jamaican Gangs, Guns and Ganja (TV Episode) #2»
#   [413] Jamaican Gangster   «Jamaican Gangster»
#   [414] Jamaican Georgian architecture   «Jamaican Georgian architecture»
#   [415] Jamaican Getaway (Musical Recording)   «Jamaican Getaway (Musical Recording)»
#   [416] m.0kksr5_   «Jamaican Getaway»
#   [417] Jamaican Girl (Canonical Version) #3   «Jamaican Girl (Canonical Version) #3»
#   [418] Jamaican Girl (Canonical Version) #4   «Jamaican Girl (Canonical Version) #4»
#   [419] Jamaican Girl (Musical Recording) #1   «Jamaican Girl (Musical Recording) #1»
#   [420] Jamaican Girl (Musical Recording) #2   «Jamaican Girl (Musical Recording) #2»
#   [421] Jamaican Girl (Musical Recording) #5   «Jamaican Girl (Musical Recording) #5»
#   [422] Jamaican Girl (explicit) (Musical Recording)   «Jamaican Girl (explicit) (Musical Recording)»
#   [423] m.0n336wk   «Jamaican Girl (explicit)»
#   [424] m.0kr_98v   «Jamaican Girl»
#   [425] m.0kwlx68   «Jamaican Girl»
#   [426] m.0l5xc58   «Jamaican Girl»
#   [427] m.0llcx8d   «Jamaican Girl»
#   [428] m.0qg6x8j   «Jamaican Girl»
#   [429] Jamaican Girl Style (Canonical Version)   «Jamaican Girl Style (Canonical Version)»
#   [430] m.0xj354t   «Jamaican Girl Style»
#   [431] Jamaican Girls (Canonical Version)   «Jamaican Girls (Canonical Version)»
#   [432] Jamaican Girls (Musical Recording) #1   «Jamaican Girls (Musical Recording) #1»
#   [433] Jamaican Girls (Musical Recording) #2   «Jamaican Girls (Musical Recording) #2»
#   [434] m.0kkhs0t   «Jamaican Girls»
#   [435] m.0mqgxbm   «Jamaican Girls»
#   [436] m.0yb5ynl   «Jamaican Girls»
#   [437] Jamaican Gold   «Jamaican Gold»
#   [438] Jamaican Gold (Canonical Version)   «Jamaican Gold (Canonical Version)»
#   [439] m.0sk04xm   «Jamaican Gold»
#   [440] Jamaican Grass   «Jamaican Grass»
#   [441] m.0kllr3n   «Jamaican Grass»
#   [442] m.0sl86mp   «Jamaican Grass»
#   [443] Jamaican Gun Sling (Musical Recording)   «Jamaican Gun Sling (Musical Recording)»
#   [444] m.0m8f4h7   «Jamaican Gun Sling»
#   [445] Jamaican Hairdresser   «Jamaican Hairdresser»
#   [446] Jamaican Heroes   «Jamaican Heroes»
#   [447] Jamaican Heroes (Musical Recording) #1   «Jamaican Heroes (Musical Recording) #1»
#   [448] m.0ljhm63   «Jamaican Heroes»
#   [449] m.0lk_9hv   «Jamaican Heroes»
#   [450] m.0lrzjsn   «Jamaican Heroes»
#   [451] m.0m6307k   «Jamaican Heroes»
#   [452] Jamaican History (version) (Musical Recording)   «Jamaican History (version) (Musical Recording)»
#   [453] m.0l8mmr8   «Jamaican History (version)»
#   [454] Jamaican Holiday (Canonical Version)   «Jamaican Holiday (Canonical Version)»
#   [455] m.0ltktyg   «Jamaican Holiday»
#   [456] Jamaican Homecoming (Composition)   «Jamaican Homecoming (Composition)»
#   [457] Jamaican Homecoming (Musical Recording)   «Jamaican Homecoming (Musical Recording)»
#   [458] m.0lrxby4   «Jamaican Homecoming»
#   [459] Jamaican House Revenge (Canonical Version)   «Jamaican House Revenge (Canonical Version)»
#   [460] m.0_jq70b   «Jamaican House Revenge»
#   [461] Jamaican House of Representatives   «Jamaican House of Representatives»
#   [462] Jamaican Ibis   «Jamaican Ibis»
#   [463] Jamaican In New York (Musical Recording) #2   «Jamaican In New York (Musical Recording) #2»
#   [464] Jamaican In New York (Musical Recording) #3   «Jamaican In New York (Musical Recording) #3»
#   [465] Jamaican In New York (Musical Recording) #4   «Jamaican In New York (Musical Recording) #4»
#   [466] m.0kw7md2   «Jamaican In New York»
#   [467] m.0kww9sd   «Jamaican In New York»
#   [468] m.0lmdffd   «Jamaican In New York»
#   [469] m.0lqmvdt   «Jamaican In New York»
#   [470] m.0ltl09m   «Jamaican In New York»
#   [471] m.0qd_1qq   «Jamaican In New York»
#   [472] Jamaican Jam (Musical Recording)   «Jamaican Jam (Musical Recording)»
#   [473] m.0mq3g1f   «Jamaican Jam»
#   [474] Jamaican Jamboree (Canonical Version)   «Jamaican Jamboree (Canonical Version)»
#   [475] m.0xdgxpj   «Jamaican Jamboree»
#   [476] Jamaican Jammin' (Canonical Version)   «Jamaican Jammin' (Canonical Version)»
#   [477] m.0sjmlg6   «Jamaican Jammin'»
#   [478] Jamaican Jig (Abashanti remix) (Musical Recording)   «Jamaican Jig (Abashanti remix) (Musical Recording)»
#   [479] Jamaican Jig (Musical Recording)   «Jamaican Jig (Musical Recording)»
#   [480] m.0kmx_tq   «Jamaican Jig (Abashanti remix)»
#   [481] m.0kt97zg   «Jamaican Jig»
#   [482] Jamaican Jigglers (Musical Recording)   «Jamaican Jigglers (Musical Recording)»
#   [483] m.0l5_ffx   «Jamaican Jigglers»
#   [484] Jamaican Joint (feat. Cam'ron and Juelz Santana) (Musical Recording)   «Jamaican Joint (feat. Cam'ron and Juelz Santana) (Musical Recording)»
#   [485] m.0n87f1b   «Jamaican Joint (feat. Cam'ron and Juelz Santana)»
#   [486] Jamaican Lady   «Jamaican Lady»
#   [487] Jamaican Lady (Canonical Version)   «Jamaican Lady (Canonical Version)»
#   [488] Jamaican Lady (Musical Recording) #1   «Jamaican Lady (Musical Recording) #1»
#   [489] Jamaican Lady (interlude) (Musical Recording) #3   «Jamaican Lady (interlude) (Musical Recording) #3»
#   [490] Jamaican Lady (interlude) (Musical Recording) #1   «Jamaican Lady (interlude) (Musical Recording) #1»
#   [491] Jamaican Lady (interlude) (Musical Recording) #2   «Jamaican Lady (interlude) (Musical Recording) #2»
#   [492] Jamaican Lady (interlude) (Musical Recording) #4   «Jamaican Lady (interlude) (Musical Recording) #4»
#   [493] m.0mfjqyz   «Jamaican Lady (interlude)»
#   [494] m.0mfjs2_   «Jamaican Lady (interlude)»
#   [495] m.0mfjs5y   «Jamaican Lady (interlude)»
#   [496] m.0mfjscf   «Jamaican Lady (interlude)»
#   [497] m.0mfjr_l   «Jamaican Lady»
#   [498] m.0mj4fn_   «Jamaican Lady»
#   [499] m.0st_4d6   «Jamaican Lady»
#   [500] Jamaican Lizard Cuckoo   «Jamaican Lizard Cuckoo»
#   [501] Jamaican Luau   «Jamaican Luau»
#   [502] m.0mw8g57   «Jamaican Luau»
#   [503] Jamaican Mango   «Jamaican Mango»
#   [504] Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases) (Canonical Version)   «Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases) (Canonical Version)»
#   [505] m.0xb7sb3   «Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases)»
#   [506] m.0yc0lx8   «Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases)»
#   [507] Jamaican Market Place (Canonical Version) #1   «Jamaican Market Place (Canonical Version) #1»
#   [508] Jamaican Market Place (Canonical Version) #2   «Jamaican Market Place (Canonical Version) #2»
#   [509] Jamaican Market Place (Musical Recording)   «Jamaican Market Place (Musical Recording)»
#   [510] m.0kwdx6c   «Jamaican Market Place»
#   [511] m.0mq69j0   «Jamaican Market Place»
#   [512] m.0y9g0x8   «Jamaican Market Place»
#   [513] Jamaican Marketplace (Musical Recording)   «Jamaican Marketplace (Musical Recording)»
#   [514] m.0mxj6_f   «Jamaican Marketplace»
#   [515] Jamaican Maroon spirit-possession language   «Jamaican Maroon spirit-possession language»
#   [516] Jamaican Me Crazy (Canonical Version)   «Jamaican Me Crazy (Canonical Version)»
#   [517] Jamaican Me Crazy (Musical Recording)   «Jamaican Me Crazy (Musical Recording)»
#   [518] Jamaican Me Crazy (TV Episode) #1   «Jamaican Me Crazy (TV Episode) #1»
#   [519] Jamaican Me Crazy (TV Episode) #2   «Jamaican Me Crazy (TV Episode) #2»
#   [520] Jamaican Me Crazy (TV Episode) #3   «Jamaican Me Crazy (TV Episode) #3»
#   [521] m.0l_gvgl   «Jamaican Me Crazy»
#   [522] m.0mfmy00   «Jamaican Me Crazy»
#   [523] Jamaican Me Hungry   «Jamaican Me Hungry»
#   [524] Jamaican Medley: Kingston Town / Banana Boat (Musical Recording)   «Jamaican Medley: Kingston Town / Banana Boat (Musical Recording)»
#   [525] m.0mj108x   «Jamaican Medley: Kingston Town / Banana Boat»
#   [526] Jamaican Mess Around (Canonical Version)   «Jamaican Mess Around (Canonical Version)»
#   [527] m.0ls3dg3   «Jamaican Mess Around»
#   [528] Jamaican Midnight   «Jamaican Midnight»
#   [529] Jamaican Ministry of Local Government, Community Development & Sport   «Jamaican Ministry of Local Government, Community Development & Sport»
#   [530] Jamaican Ministry of Tourism and Sports   «Jamaican Ministry of Tourism and Sports»
#   [531] Jamaican Monk (Composition)   «Jamaican Monk (Composition)»
#   [532] Jamaican Monk (Musical Recording)   «Jamaican Monk (Musical Recording)»
#   [533] m.0k_hh5h   «Jamaican Monk»
#   [534] m.0m6506q   «Jamaican Monk»
#   [535] m.0skydw4   «Jamaican Monk»
#   [536] Jamaican Monkey Man (Multi-Part Musical Release)   «Jamaican Monkey Man (Multi-Part Musical Release)»
#   [537] Jamaican Monkey Man (Musical Album)   «Jamaican Monkey Man (Musical Album)»
#   [538] Jamaican Mule (Canonical Version)   «Jamaican Mule (Canonical Version)»
#   [539] m.0sjhtkz   «Jamaican Mule»
#   [540] Jamaican Night   «Jamaican Night»
#   [541] m.0m0v0yg   «Jamaican Night»
#   [542] Jamaican Nightingale   «Jamaican Nightingale»
#   [543] Jamaican Nights (Musical Recording)   «Jamaican Nights (Musical Recording)»
#   [544] m.0lwnv46   «Jamaican Nights»
#   [545] Jamaican Noel (Musical Recording) #1   «Jamaican Noel (Musical Recording) #1»
#   [546] Jamaican Noel (Musical Recording) #2   «Jamaican Noel (Musical Recording) #2»
#   [547] m.0ljc7dv   «Jamaican Noel»
#   [548] m.0m_7kl3   «Jamaican Noel»
#   [549] Jamaican Oriole   «Jamaican Oriole»
#   [550] Jamaican Owl   «Jamaican Owl»
#   [551] Jamaican People (Canonical Version)   «Jamaican People (Canonical Version)»
#   [552] m.0kt6gts   «Jamaican People»
#   [553] Jamaican Petrel   «Jamaican Petrel»
#   [554] Jamaican Pewee   «Jamaican Pewee»
#   [555] Jamaican Place (Musical Recording)   «Jamaican Place (Musical Recording)»
#   [556] m.0ldgp04   «Jamaican Place»
#   [557] m.0mbjg03   «Jamaican Place»
#   [558] Jamaican Police (Canonical Version)   «Jamaican Police (Canonical Version)»
#   [559] m.0ls5cx8   «Jamaican Police»
#   [560] Jamaican Poorwill   «Jamaican Poorwill»
#   [561] Jamaican Praise Medley   «Jamaican Praise Medley»
#   [562] m.0mnqr0x   «Jamaican Praise Medley»
#   [563] Jamaican Proverb (Musical Recording) #1   «Jamaican Proverb (Musical Recording) #1»
#   [564] Jamaican Proverb (Musical Recording) #2   «Jamaican Proverb (Musical Recording) #2»
#   [565] m.0ktm6gd   «Jamaican Proverb»
#   [566] m.0lv_4l2   «Jamaican Proverb»
#   [567] m.0m5kvv1   «Jamaican Proverb»
#   [568] Jamaican Radio Edit (Canonical Version)   «Jamaican Radio Edit (Canonical Version)»
#   [569] m.0lw2ms3   «Jamaican Radio Edit»
#   [570] Jamaican Radio Obituary   «Jamaican Radio Obituary»
#   [571] m.0knjndc   «Jamaican Radio Obituary»
#   [572] Jamaican Recordings (Musical Album)   «Jamaican Recordings (Musical Album)»
#   [573] Jamaican Red Macaw   «Jamaican Red Macaw»
#   [574] Jamaican Rhumba   «Jamaican Rhumba»
#   [575] Jamaican Rumba (Musical Recording) #13   «Jamaican Rumba (Musical Recording) #13»
#   [576] Jamaican Rumba (Composition)   «Jamaican Rumba (Composition)»
#   [577] Jamaican Rhumba (Canonical Version)   «Jamaican Rhumba (Canonical Version)»
#   [578] Jamaican Rhumba (Musical Recording) #1   «Jamaican Rhumba (Musical Recording) #1»
#   [579] Jamaican Rhumba (Musical Recording) #2   «Jamaican Rhumba (Musical Recording) #2»
#   [580] Jamaican Rhumba (Musical Recording) #3   «Jamaican Rhumba (Musical Recording) #3»
#   [581] m.0kldzcr   «Jamaican Rhumba»
#   [582] m.0l25gcr   «Jamaican Rhumba»
#   [583] m.0mq2rws   «Jamaican Rhumba»
#   [584] m.0mr94mg   «Jamaican Rhumba»
#   [585] m.0yb2sck   «Jamaican Rhumba»
#   [586] Jamaican Robot (Musical Recording)   «Jamaican Robot (Musical Recording)»
#   [587] m.0m8vw_r   «Jamaican Robot»
#   [588] Jamaican Rock (Composition)   «Jamaican Rock (Composition)»
#   [589] Jamaican Rock (Musical Recording)   «Jamaican Rock (Musical Recording)»
# ...
#   [942] Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Musical Album)   «Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Musical Album)»
#   [943] Reggae Love Songs: 50 Jamaican Lovers Classics (Musical Album)   «Reggae Love Songs: 50 Jamaican Lovers Classics (Musical Album)»
#   [944] Reggae explosion : the story of Jamaican music   «Reggae explosion : the story of Jamaican music»
#   [945] Reggae on Broadway (Jamaican mix) (Musical Recording)   «Reggae on Broadway (Jamaican mix) (Musical Recording)»
#   [946] m.0m4rs6k   «Reggae on Broadway (Jamaican mix)»
#   [947] Renewing democracy into the millennium : the Jamaican experience in perpective   «Renewing democracy into the millennium : the Jamaican experience in perpective»
#   [948] Respect to Jamaican Dons (Musical Recording)   «Respect to Jamaican Dons (Musical Recording)»
#   [949] m.0mkm_9x   «Respect to Jamaican Dons»
#   [950] Responses of Jamaican and American deaf groups to stigma   «Responses of Jamaican and American deaf groups to stigma»
#   [951] Responses of Jamaican and American deaf groups to stigma : a critical interpretive approach   «Responses of Jamaican and American deaf groups to stigma : a critical interpretive approach»
#   [952] Rock to the Rock (original Jamaican Soul mix) (Musical Recording)   «Rock to the Rock (original Jamaican Soul mix) (Musical Recording)»
#   [953] m.0m4rrr0   «Rock to the Rock (original Jamaican Soul mix)»
#   [954] Rocking Steady (original Jamaican Soul mix) (Musical Recording)   «Rocking Steady (original Jamaican Soul mix) (Musical Recording)»
#   [955] m.0ly8v9k   «Rocking Steady (original Jamaican Soul mix)»
#   [956] The Jamaican Shower Posse   «The Jamaican Shower Posse»
#   [957] Roots & Urban Culture: Una muestra del legado jamaicano (Musical Album)   «Roots & Urban Culture: Una muestra del legado jamaicano (Musical Album)»
#   [958] Roots Reggae: The Classic Jamaican Albums (Musical Album)   «Roots Reggae: The Classic Jamaican Albums (Musical Album)»
#   [959] Roots Reggae: The Classic Jamaican Albums (disc 1: The Sensational Maytals)   «Roots Reggae: The Classic Jamaican Albums (disc 1: The Sensational Maytals)»
#   [960] Roots Reggae: The Classic Jamaican Albums (disc 2: Sweet and Dandy)   «Roots Reggae: The Classic Jamaican Albums (disc 2: Sweet and Dandy)»
#   [961] Roots Reggae: The Classic Jamaican Albums (disc 3: Monkey Man)   «Roots Reggae: The Classic Jamaican Albums (disc 3: Monkey Man)»
#   [962] Roots Reggae: The Classic Jamaican Albums (disc 4: The Maytals Greatest Hits)   «Roots Reggae: The Classic Jamaican Albums (disc 4: The Maytals Greatest Hits)»
#   [963] Roots Reggae: The Classic Jamaican Albums (disc 5: Slatyam Stoot)   «Roots Reggae: The Classic Jamaican Albums (disc 5: Slatyam Stoot)»
#   [964] Roots Reggae: The Classic Jamaican Albums (disc 6: Roots Reggae)   «Roots Reggae: The Classic Jamaican Albums (disc 6: Roots Reggae)»
#   [965] Roots of Jamaican culture   «Roots of Jamaican culture»
#   [966] Roots of Jamaican culture (Book Edition)   «Roots of Jamaican culture (Book Edition)»
#   [967] Rosenś speak Jamaican (Book Edition)   «Rosenś speak Jamaican (Book Edition)»
#   [968] Rosenś speak Jamaican (Book)   «Rosenś speak Jamaican (Book)»
#   [969] Rude Boy Jamaican (Musical Recording) #1   «Rude Boy Jamaican (Musical Recording) #1»
#   [970] Rude Boy Jamaican (Musical Recording) #2   «Rude Boy Jamaican (Musical Recording) #2»
#   [971] m.0ll9128   «Rude Boy Jamaican»
#   [972] m.0ly4bmb   «Rude Boy Jamaican»
#   [973] Run Tings (100% Jamaican dub plates) (Musical Album)   «Run Tings (100% Jamaican dub plates) (Musical Album)»
#   [974] Rural-urban migration and the Jamaican child   «Rural-urban migration and the Jamaican child»
#   [975] Scottish Jamaican   «Scottish Jamaican»
#   [976] Secret Heaven (Jamaican Heaven mix) (Musical Recording)   «Secret Heaven (Jamaican Heaven mix) (Musical Recording)»
#   [977] m.0kqv2f4   «Secret Heaven (Jamaican Heaven mix)»
#   [978] Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book Edition)   «Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book Edition)»
#   [979] Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book)   «Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book)»
#   [980] Sha La La I Need You (Jamaican mix) (Canonical Version)   «Sha La La I Need You (Jamaican mix) (Canonical Version)»
#   [981] m.0y1hhvs   «Sha La La I Need You (Jamaican mix)»
#   [982] Shock Out Jamaican Style (Musical Recording)   «Shock Out Jamaican Style (Musical Recording)»
#   [983] m.0lrm5b_   «Shock Out Jamaican Style»
#   [984] Six great Jamaicans   «Six great Jamaicans»
#   [985] Ska Boogie: Jamaican R&B, the Dawn of Ska (Musical Album)   «Ska Boogie: Jamaican R&B, the Dawn of Ska (Musical Album)»
#   [986] Slaves and missionaries : the disintegration of Jamaican slave society, 1787-1834   «Slaves and missionaries : the disintegration of Jamaican slave society, 1787-1834»
#   [987] Sled Shred featuring the Jamaican bobsled team (Sports Video Game)   «Sled Shred featuring the Jamaican bobsled team (Sports Video Game)»
#   [988] Sled Shred featuring the Jamaican bobsled team (Video Game Version)   «Sled Shred featuring the Jamaican bobsled team (Video Game Version)»
#   [989] Slum Dogz Vs. Pimento Jamaican Kitchen   «Slum Dogz Vs. Pimento Jamaican Kitchen»
#   [990] Snoop Dogg: The Jamaican Episode   «Snoop Dogg: The Jamaican Episode»
#   [991] Social change and social mobility in a Jamaican rural community   «Social change and social mobility in a Jamaican rural community»
#   [992] Soon come : Jamaican spirituality, Jamaican poetics   «Soon come : Jamaican spirituality, Jamaican poetics»
#   [993] Soul Revolutionaries: The Early Jamaican Albums (Multi-Part Musical Release)   «Soul Revolutionaries: The Early Jamaican Albums (Multi-Part Musical Release)»
#   [994] Soul Revolutionaries: The Early Jamaican Albums (Musical Album)   «Soul Revolutionaries: The Early Jamaican Albums (Musical Album)»
#   [995] Soundsystem: The Story of Jamaican Music (Musical Album)   «Soundsystem: The Story of Jamaican Music (Musical Album)»
#   [996] Sources of Jamaican history, 1655-1838   «Sources of Jamaican history, 1655-1838»
#   [997] Sources of Jamaican history, 1655-1838 : a bibliographical survey with particular reference to manuscript sources   «Sources of Jamaican history, 1655-1838 : a bibliographical survey with particular reference to manuscript sources»
#   [998] Standing Tall: Affirmations of the Jamaican Male   «Standing Tall: Affirmations of the Jamaican Male»
#   [999] Stoned Out of My Mind (Jamaican mix) (Musical Recording)   «Stoned Out of My Mind (Jamaican mix) (Musical Recording)»
#   [1000] m.0ly3s9w   «Stoned Out of My Mind (Jamaican mix)»
#   [1001] Struggles of the Jamaican people   «Struggles of the Jamaican people»
#   [1002] Sugar Cane (Jamaican Style) (Musical Recording)   «Sugar Cane (Jamaican Style) (Musical Recording)»
#   [1003] m.0mf2yw9   «Sugar Cane (Jamaican Style)»
#   [1004] The Classic Jamaican Recordings Finest Vocal Trio (Musical Album)   «The Classic Jamaican Recordings Finest Vocal Trio (Musical Album)»
#   [1005] The Jamaican (Canonical Version) #1   «The Jamaican (Canonical Version) #1»
#   [1006] The Jamaican (Canonical Version) #2   «The Jamaican (Canonical Version) #2»
#   [1007] The Jamaican (Musical Recording)   «The Jamaican (Musical Recording)»
#   [1008] m.0km_4m8   «The Jamaican»
#   [1009] m.0lkhmzf   «The Jamaican»
#   [1010] m.0msf4wy   «The Jamaican»
#   [1011] The Jamaican Beat (Musical Album)   «The Jamaican Beat (Musical Album)»
#   [1012] The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Musical Album)   «The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Musical Album)»
#   [1013] The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Musical Album)   «The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Musical Album)»
#   [1014] The Jamaican Dub Versions, Volume 2 (Musical Album)   «The Jamaican Dub Versions, Volume 2 (Musical Album)»
#   [1015] The Jamaican Episode (Musical Album)   «The Jamaican Episode (Musical Album)»
#   [1016] The Jamaican Exchange   «The Jamaican Exchange»
#   [1017] The Jamaican crime scene   «The Jamaican crime scene»
#   [1018] The Jamaican crime scene : a perspective   «The Jamaican crime scene : a perspective»
#   [1019] The Jamaican economy   «The Jamaican economy»
#   [1020] The Jamaican economy in the 1980s   «The Jamaican economy in the 1980s»
#   [1021] The Jamaican economy in the 1980s: economic decline and structural adjustment   «The Jamaican economy in the 1980s: economic decline and structural adjustment»
#   [1022] The Jamaican people 1880-1902  : race, class and social control   «The Jamaican people 1880-1902  : race, class and social control»
#   [1023] The Jamaican stage, 1655-1900   «The Jamaican stage, 1655-1900»
#   [1024] The Jamaican stage, 1655-1900: profile of a colonial theatre   «The Jamaican stage, 1655-1900: profile of a colonial theatre»
#   [1025] The Jamaicans (Book Edition)   «The Jamaicans (Book Edition)»
#   [1026] The Jamaicans (Book)   «The Jamaicans (Book)»
#   [1027] The Long Hot Summer: Jamaican Ska 1963 (Musical Album)   «The Long Hot Summer: Jamaican Ska 1963 (Musical Album)»
#   [1028] The Pioneer of Jamaican Music (Musical Album)   «The Pioneer of Jamaican Music (Musical Album)»
#   [1029] The Reggae Box: The Routes of Jamaican Music (Musical Album)   «The Reggae Box: The Routes of Jamaican Music (Musical Album)»
#   [1030] The Two Jamaican Girls   «The Two Jamaican Girls»
#   [1031] The cold war and the Jamaican Left, 1950-1955   «The cold war and the Jamaican Left, 1950-1955»
#   [1032] The development of Jamaican popular music, with special reference to the music of Bob Marley   «The development of Jamaican popular music, with special reference to the music of Bob Marley»
#   [1033] The development of Jamaican popular music, with special reference to the music of Bob Marley : a bibliography   «The development of Jamaican popular music, with special reference to the music of Bob Marley : a bibliography»
#   [1034] The hills of Hebron, a Jamaican novel   «The hills of Hebron, a Jamaican novel»
#   [1035] The household survey as a tool for policy change: lessons from the Jamaican survey of living conditions   «The household survey as a tool for policy change: lessons from the Jamaican survey of living conditions»
#   [1036] The incidence of Jamaican taxes, 1971-72 (Book Edition)   «The incidence of Jamaican taxes, 1971-72 (Book Edition)»
#   [1037] The incidence of Jamaican taxes, 1971-72 (Book)   «The incidence of Jamaican taxes, 1971-72 (Book)»
#   [1038] The mother of us all : a history of Queen Nanny, leader of the Windward Jamaican Maroons   «The mother of us all : a history of Queen Nanny, leader of the Windward Jamaican Maroons»
#   [1039] The political opinions of the Jamaican people   «The political opinions of the Jamaican people»
#   [1040] The political opinions of the Jamaican people (1976-81)   «The political opinions of the Jamaican people (1976-81)»
#   [1041] The power of sentiment : love, hierarchy, and the Jamaican family elite   «The power of sentiment : love, hierarchy, and the Jamaican family elite»
#   [1042] The sun and the drum : African roots in Jamaican folk tradition   «The sun and the drum : African roots in Jamaican folk tradition»
#   [1043] The syntax of Jamaican Creole   «The syntax of Jamaican Creole»
#   [1044] The syntax of Jamaican Creole : a cartographic perspective   «The syntax of Jamaican Creole : a cartographic perspective»
#   [1045] Ti si ta (Jamaican remix) (Musical Recording)   «Ti si ta (Jamaican remix) (Musical Recording)»
#   [1046] m.0my3d3w   «Ti si ta (Jamaican remix)»
#   [1047] Too Much Love (extended version) (Jamaican mix) (Musical Recording)   «Too Much Love (extended version) (Jamaican mix) (Musical Recording)»
#   [1048] m.0ly3s7m   «Too Much Love (extended version) (Jamaican mix)»
#   [1049] Tougher Than Tough: The Story of Jamaican Music (Multi-Part Musical Release)   «Tougher Than Tough: The Story of Jamaican Music (Multi-Part Musical Release)»
#   [1050] Tougher Than Tough: The Story of Jamaican Music (Musical Album)   «Tougher Than Tough: The Story of Jamaican Music (Musical Album)»
#   [1051] Trojan Jamaican Hits Box Set (Musical Album)   «Trojan Jamaican Hits Box Set (Musical Album)»
#   [1052] Trojan Jamaican R&B Box Set (Musical Album)   «Trojan Jamaican R&B Box Set (Musical Album)»
#   [1053] Trojan Jamaican Superstars Box Set (Musical Album)   «Trojan Jamaican Superstars Box Set (Musical Album)»
#   [1054] Trojan: Classic Jamaican Sounds Since 1968 (Musical Album)   «Trojan: Classic Jamaican Sounds Since 1968 (Musical Album)»
#   [1055] Try Me (Jamaican Blend mix) (Musical Recording)   «Try Me (Jamaican Blend mix) (Musical Recording)»
#   [1056] m.0n36lkz   «Try Me (Jamaican Blend mix)»
#   [1057] Twin Spin (Jamaican session demo) (Musical Recording)   «Twin Spin (Jamaican session demo) (Musical Recording)»
#   [1058] m.0l24pw4   «Twin Spin (Jamaican session demo)»
#   [1059] m.0m5kvvx   «Twin Spin (Jamaican session demo)»
#   [1060] Two Jamaican Pieces   «Two Jamaican Pieces»
#   [1061] UK Jamaican (Musical Recording)   «UK Jamaican (Musical Recording)»
#   [1062] m.0mp31t4   «UK Jamaican»
#   [1063] m.0mrc576   «UK Jamaican»
#   [1064] Un Jamaicano Vero (Musical Recording)   «Un Jamaicano Vero (Musical Recording)»
#   [1065] m.0mn7sf7   «Un Jamaicano Vero»
#   [1066] Under the Jamaican Moon (Musical Recording)   «Under the Jamaican Moon (Musical Recording)»
#   [1067] m.0mr4c6w   «Under the Jamaican Moon»
#   [1068] Vaguely Jamaican   «Vaguely Jamaican»
#   [1069] m.0mh51mg   «Vaguely Jamaican»
#   [1070] Variations in some Jamaican species of Pleurodonte (Book Edition)   «Variations in some Jamaican species of Pleurodonte (Book Edition)»
#   [1071] Variations in some Jamaican species of Pleurodonte (Book)   «Variations in some Jamaican species of Pleurodonte (Book)»
#   [1072] Walk Like a Jamaican (Musical Recording)   «Walk Like a Jamaican (Musical Recording)»
#   [1073] m.0m8sb02   «Walk Like a Jamaican»
#   [1074] We Are Da Click (Blockster Jamaican Me Funkin' Crazy radio edit) (Musical Recording)   «We Are Da Click (Blockster Jamaican Me Funkin' Crazy radio edit) (Musical Recording)»
#   [1075] m.0xbbw3q   «We Are Da Click (Blockster Jamaican Me Funkin' Crazy radio edit)»
#   [1076] We Jamaican (Musical Recording)   «We Jamaican (Musical Recording)»
#   [1077] m.0mngcrg   «We Jamaican»
#   [1078] What Jamaican? (feat. Anthony Jackson) (Canonical Version)   «What Jamaican? (feat. Anthony Jackson) (Canonical Version)»
#   [1079] m.0n6ll0x   «What Jamaican? (feat. Anthony Jackson)»
#   [1080] What You Gon' Do (Jamaican mix) (Musical Recording)   «What You Gon' Do (Jamaican mix) (Musical Recording)»
#   [1081] m.0kk0r3x   «What You Gon' Do (Jamaican mix)»
#   [1082] When the Lights Gone Out (Jamaican Stylee) (Musical Recording)   «When the Lights Gone Out (Jamaican Stylee) (Musical Recording)»
#   [1083] m.0ljsdfx   «When the Lights Gone Out (Jamaican Stylee)»
#   [1084] m.0mws_r2   «When the Lights Gone Out (Jamaican Stylee)»
#   [1085] Which Way You Going Baby (Jamaican mix) (Musical Recording)   «Which Way You Going Baby (Jamaican mix) (Musical Recording)»
#   [1086] m.0ly3s9d   «Which Way You Going Baby (Jamaican mix)»
#   [1087] Work Your Soul: Jamaican 60s & Northern 1966-74 (Musical Album)   «Work Your Soul: Jamaican 60s & Northern 1966-74 (Musical Album)»
#   [1088] Yellow Bird / Jamaican Farewell (Musical Recording)   «Yellow Bird / Jamaican Farewell (Musical Recording)»
#   [1089] m.0mmzks5   «Yellow Bird / Jamaican Farewell»
#   [1090] Ziggy (Jamaican session demo) (Musical Recording)   «Ziggy (Jamaican session demo) (Musical Recording)»
#   [1091] m.0l24pvx   «Ziggy (Jamaican session demo)»
#   [1092] m.0m5kvqj   «Ziggy (Jamaican session demo)»

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

SIMILARITY_MODEL = "sentence-transformers/all-MiniLM-L6-v2"
TOP_K_CANDIDATES = 5

def calculate_candidate_similarity(question, candidates, model_name=SIMILARITY_MODEL, top_k=TOP_K_CANDIDATES):
    if not candidates:
        return []
    
    print(f"[INFO] Loading similarity model: {model_name}")
    model = SentenceTransformer(model_name)
    
    # Prepare texts for encoding
    question_text = question.strip()
    candidate_texts = []
    
    for mid, name in candidates:
        candidate_text = f"{name}"
        
        # Add some context if the name is very short
        if len(name.split()) < 2:
            candidate_text = f"entity named {name}"
            
        candidate_texts.append(candidate_text)
    
    print(f"[INFO] Encoding question and {len(candidates)} candidates...")
    
    # Encode question and candidates
    question_embedding = model.encode([question_text])
    candidate_embeddings = model.encode(candidate_texts)
    
    # Calculate cosine similarities
    similarities = cosine_similarity(question_embedding, candidate_embeddings)[0]
    
    # Create scored candidates
    scored_candidates = []
    for i, (mid, name) in enumerate(candidates):
        scored_candidates.append((mid, name, similarities[i]))
    
    # Sort by similarity (descending) and take top-k
    scored_candidates.sort(key=lambda x: x[2], reverse=True)
    top_candidates = scored_candidates[:top_k]
    
    print(f"[INFO] Top {len(top_candidates)} candidates by similarity:")
    for i, (mid, name, score) in enumerate(top_candidates, 1):
        print(f"  [{i}] {score:.4f} - {mid} «{name}»")
    
    return top_candidates

# %%
candidates1=calculate_candidate_similarity(question, candidates)
# Out:
# [INFO] Loading similarity model: sentence-transformers/all-MiniLM-L6-v2
# [INFO] Encoding question and 1092 candidates...
# [INFO] Top 5 candidates by similarity:
#   [1] 0.8282 - m.0lsyw5q «Distinguished Jamaican English»
#   [2] 0.8187 - How to speak Jamaican? (Book) «How to speak Jamaican? (Book)»
#   [3] 0.8126 - Jamaican Creole English Language «Jamaican Creole English Language»
#   [4] 0.8007 - Jamaican Creole «Jamaican Creole»
#   [5] 0.7984 - Jamaican English «Jamaican English»

# %%
final_candidates = [(mid, name) for mid, name, score in candidates1]

# %%
candidates
# Out:
# [('Jamaican', 'Jamaican'),
#  ('m.0lp70fh', 'Jamaican'),
#  ('m.0m38_m4', 'Jamaican'),
#  ('m.0mbvqy_', 'Jamaican'),
#  ('m.0mlgpx9', 'Jamaican'),
#  ('m.0mv164s', 'Jamaican'),
#  ('m.0n6kx9t', 'Jamaican'),
#  ('"Assertive \'no\' in Jamaican Creole" (Book Edition)',
#   '"Assertive \'no\' in Jamaican Creole" (Book Edition)'),
#  ('"Assertive \'no\' in Jamaican Creole" (Book)',
#   '"Assertive \'no\' in Jamaican Creole" (Book)'),
#  ('Jamaican Barbie', 'Jamaican Barbie'),
#  ('Trojan Jamaican R&B Box Set (Consumer product)',
#   'Trojan Jamaican R&B Box Set (Consumer product)'),
#  ('Jamaican Style (Consumer product)', 'Jamaican Style (Consumer product)'),
#  ('Roots Reggae: The Classic Jamaican Albums (Multi-Part Musical Release)',
#   'Roots Reggae: The Classic Jamaican Albums (Multi-Part Musical Release)'),
#  ('Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Compact Disc Musical Release)',
#   'Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Compact Disc Musical Release)'),
#  ('(To Be) Young, Gifted & Black (Jamaican mix) (Musical Recording)',
#   '(To Be) Young, Gifted & Black (Jamaican mix) (Musical Recording)'),
#  ('m.0l6pwt0', '(To Be) Young, Gifted & Black (Jamaican mix)'),
#  ('Tougher Than Tough: The Story of Jamaican Music (Consumer product)',
#   'Tougher Than Tough: The Story of Jamaican Music (Consumer product)'),
#  ('Soundsystem: The Story of Jamaican Music (Compact Disc Musical Release)',
#   'Soundsystem: The Story of Jamaican Music (Compact Disc Musical Release)'),
#  ('Jamaican Street Legal', 'Jamaican Street Legal'),
#  ('Jamaican E.T. (Consumer product) #3',
#   'Jamaican E.T. (Consumer product) #3'),
#  ('Jamaican E.T. (Consumer product) #4',
#   'Jamaican E.T. (Consumer product) #4'),
#  ('Love Forever: The Classic Jamaican Recordings (Compact Disc Musical Release)',
#   'Love Forever: The Classic Jamaican Recordings (Compact Disc Musical Release)'),
#  ('Montego Bay - Jamaican Persuasion (Compact Disc Musical Release)',
#   'Montego Bay - Jamaican Persuasion (Compact Disc Musical Release)'),
#  ('The Reggae Box: The Routes of Jamaican Music (Compact Disc Musical Release)',
#   'The Reggae Box: The Routes of Jamaican Music (Compact Disc Musical Release)'),
#  ('The Jamaican Episode (Compact Disc Musical Release)',
#   'The Jamaican Episode (Compact Disc Musical Release)'),
#  ('2 Sounds (Jamaican Icetea version) (Musical Recording)',
#   '2 Sounds (Jamaican Icetea version) (Musical Recording)'),
#  ('m.0mv6ww2', '2 Sounds (Jamaican Icetea version)'),
#  ('Arise Rootsman: Jamaican Roots 1965-1983 (Compact Disc Musical Release)',
#   'Arise Rootsman: Jamaican Roots 1965-1983 (Compact Disc Musical Release)'),
#  ('The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)',
#   'The Jamaican Beat, Volume 2 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)'),
#  ('Soul Revolutionaries: The Early Jamaican Albums (Musical Release Component)',
#   'Soul Revolutionaries: The Early Jamaican Albums (Musical Release Component)'),
#  ('Catch a Fire (disc 1: The Jamaican Versions)',
#   'Catch a Fire (disc 1: The Jamaican Versions)'),
#  ('The Jamaican Dub Versions, Volume 2 (Compact Disc Musical Release)',
#   'The Jamaican Dub Versions, Volume 2 (Compact Disc Musical Release)'),
#  ('50 Years of Jamaican Music 1962 - 2012 (Compact Disc Musical Release)',
#   '50 Years of Jamaican Music 1962 - 2012 (Compact Disc Musical Release)'),
#  ('50 Years of Jamaican Music 1962 - 2012 (Musical Album)',
#   '50 Years of Jamaican Music 1962 - 2012 (Musical Album)'),
#  ('Jamaican Monkey Man (Compact Disc Musical Release)',
#   'Jamaican Monkey Man (Compact Disc Musical Release)'),
#  ('Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Compact Disc Musical Release)',
#   'Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Compact Disc Musical Release)'),
#  ('Trojan Jamaican Hits Box Set (disc 2)',
#   'Trojan Jamaican Hits Box Set (disc 2)'),
#  ('Trojan Jamaican Hits Box Set (Multi-Part Musical Release)',
#   'Trojan Jamaican Hits Box Set (Multi-Part Musical Release)'),
#  ('Bloodlines - Jamaican Dub & Roots (Consumer product)',
#   'Bloodlines - Jamaican Dub & Roots (Consumer product)'),
#  ("High Plains Drifter: Jamaican 45's 1968-73 (Consumer product)",
#   "High Plains Drifter: Jamaican 45's 1968-73 (Consumer product)"),
#  ('A Conversation With Children / Jamaican Rumba (Musical Recording)',
#   'A Conversation With Children / Jamaican Rumba (Musical Recording)'),
#  ('m.0lzwbvr', 'A Conversation With Children / Jamaican Rumba'),
#  ('m.0ms8ld4', 'A Conversation With Children / Jamaican Rumba'),
#  ("Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #2",
#   "Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #2"),
#  ("Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #1",
#   "Real Cool: The Jamaican King of the Saxophone '66-'77 (Consumer product) #1"),
#  ('A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Album)',
#   'A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Album)'),
#  ('A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Release)',
#   'A History of Jamaican Vocal Harmony: Great Reggae Trios (Musical Release)'),
#  ('A Jamaican Collection (Compact Disc Musical Release)',
#   'A Jamaican Collection (Compact Disc Musical Release)'),
#  ('A Jamaican Collection (Musical Album)',
#   'A Jamaican Collection (Musical Album)'),
#  ('A Jamaican in New York (Musical Recording) #1',
#   'A Jamaican in New York (Musical Recording) #1'),
#  ('Jamaican In New York (Musical Recording) #1',
#   'Jamaican In New York (Musical Recording) #1'),
#  ('A Jamaican in New York (Musical Recording) #2',
#   'A Jamaican in New York (Musical Recording) #2'),
#  ('A Jamaican in New York (Musical Recording) #3',
#   'A Jamaican in New York (Musical Recording) #3'),
#  ('m.0ljj22k', 'A Jamaican in New York'),
#  ('m.0lmckm2', 'A Jamaican in New York'),
#  ('m.0m6cv2l', 'A Jamaican in New York'),
#  ('m.0n2_17z', 'A Jamaican in New York'),
#  ('A Jamaican plantation', 'A Jamaican plantation'),
#  ('A Jamaican plantation: the history of Worthy Park 1670-1970',
#   'A Jamaican plantation: the history of Worthy Park 1670-1970'),
#  ("A Jamaican storyteller's tale (Book Edition)",
#   "A Jamaican storyteller's tale (Book Edition)"),
#  ("A Jamaican storyteller's tale (Book)",
#   "A Jamaican storyteller's tale (Book)"),
#  ('The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)',
#   'The Jamaican Beat, Volume 1 - Jazz Jamaica Plays Blue Note Blue Beat (Compact Disc Musical Release)'),
#  ('The Jamaican Beat (Musical Release)',
#   'The Jamaican Beat (Musical Release)'),
#  ('Jamaican Funk—Canadian Style (Consumer product)',
#   'Jamaican Funk—Canadian Style (Consumer product)'),
#  ('A boy named Ossie : a Jamaican childhood',
#   'A boy named Ossie : a Jamaican childhood'),
#  ('A man divided: Michael Garfield Smith : Jamaican poet and anthropologist, 1921-1993',
#   'A man divided: Michael Garfield Smith : Jamaican poet and anthropologist, 1921-1993'),
#  ('A reanalysis of the phonological system of Jamaican Creole (Book Edition)',
#   'A reanalysis of the phonological system of Jamaican Creole (Book Edition)'),
#  ('A reanalysis of the phonological system of Jamaican Creole (Book)',
#   'A reanalysis of the phonological system of Jamaican Creole (Book)'),
#  ('A-Z of Jamaican heritage', 'A-Z of Jamaican heritage'),
#  ('The Classic Jamaican Recordings Finest Vocal Trio (Musical Release)',
#   'The Classic Jamaican Recordings Finest Vocal Trio (Musical Release)'),
#  ('Original Cool Jamaican Ska (Compact Disc Musical Release)',
#   'Original Cool Jamaican Ska (Compact Disc Musical Release)'),
#  ('The Long Hot Summer: Jamaican Ska 1963 (Compact Cassette Musical Release)',
#   'The Long Hot Summer: Jamaican Ska 1963 (Compact Cassette Musical Release)'),
#  ('Adult and non-formal education in the Third World : a Jamaican perspective',
#   'Adult and non-formal education in the Third World : a Jamaican perspective'),
#  ('Jamaican Roots (Consumer product)', 'Jamaican Roots (Consumer product)'),
#  ('African Jamaican (Musical Recording)',
#   'African Jamaican (Musical Recording)'),
#  ('m.0ln7ykk', 'African Jamaican'),
#  ('African retentions in Jamaican Creole',
#   'African retentions in Jamaican Creole'),
#  ('African retentions in Jamaican Creole : a reassessment',
#   'African retentions in Jamaican Creole : a reassessment'),
#  ('Trojan Box Set: Jamaican Superstars (disc 3)',
#   'Trojan Box Set: Jamaican Superstars (disc 3)'),
#  ('Trojan Jamaican Superstars Box Set (Multi-Part Musical Release)',
#   'Trojan Jamaican Superstars Box Set (Multi-Part Musical Release)'),
#  ('Dancehall: The Rise of Jamaican Dancehall Culture (Compact Disc Musical Release)',
#   'Dancehall: The Rise of Jamaican Dancehall Culture (Compact Disc Musical Release)'),
#  ('Reggae Love Songs: 50 Jamaican Lovers Classics (Compact Disc Musical Release)',
#   'Reggae Love Songs: 50 Jamaican Lovers Classics (Compact Disc Musical Release)'),
#  ('Aintcha Gonna Be a Jamaican (Canonical Version)',
#   'Aintcha Gonna Be a Jamaican (Canonical Version)'),
#  ('m.0l86pdc', 'Aintcha Gonna Be a Jamaican'),
#  ('The Pioneer of Jamaican Music (Compact Disc Musical Release)',
#   'The Pioneer of Jamaican Music (Compact Disc Musical Release)'),
#  ('The Pioneer of Jamaican Music (Consumer product)',
#   'The Pioneer of Jamaican Music (Consumer product)'),
#  ('The Pioneer of Jamaican Music (Gramophone record Musical Release)',
#   'The Pioneer of Jamaican Music (Gramophone record Musical Release)'),
#  ('Jamaican American', 'Jamaican American'),
#  ("Albert's Real Jamaican Foods", "Albert's Real Jamaican Foods"),
#  ('American Guestworkers: Jamaicans And Mexicans in the U.S. Labor Market (Rural Studies)',
#   'American Guestworkers: Jamaicans And Mexicans in the U.S. Labor Market (Rural Studies)'),
#  ('An eclectic approach to estimating the determinants of achievement in Jamaican primary education',
#   'An eclectic approach to estimating the determinants of achievement in Jamaican primary education'),
#  ('Anansi, the spider man; Jamaican folk tales',
#   'Anansi, the spider man; Jamaican folk tales'),
#  ('Jamaicans of African ancestry', 'Jamaicans of African ancestry'),
#  ('Hot Jamaican Mixture (Compact Disc Musical Release)',
#   'Hot Jamaican Mixture (Compact Disc Musical Release)'),
#  ('Arise Rootsman: Jamaican Roots 1965-1983 (Musical Album)',
#   'Arise Rootsman: Jamaican Roots 1965-1983 (Musical Album)'),
#  ('Arise ye starvelings: the Jamaican labour rebellion of 1938 and its aftermath',
#   'Arise ye starvelings: the Jamaican labour rebellion of 1938 and its aftermath'),
#  ('Jamaican Queens', 'Jamaican Queens'),
#  ('Jamaican Style (Compact Disc Musical Release)',
#   'Jamaican Style (Compact Disc Musical Release)'),
#  ("Katani's Jamaican Holiday", "Katani's Jamaican Holiday"),
#  ('Roots & Urban Culture: Una muestra del legado jamaicano (Musical Release)',
#   'Roots & Urban Culture: Una muestra del legado jamaicano (Musical Release)'),
#  ('The Jamaicans', 'The Jamaicans'),
#  ('Trojan: Classic Jamaican Sounds Since 1968 (Compact Disc Musical Release)',
#   'Trojan: Classic Jamaican Sounds Since 1968 (Compact Disc Musical Release)'),
#  ('Jamaican Beat (Consumer product)', 'Jamaican Beat (Consumer product)'),
#  ('Work Your Soul: Jamaican 60s & Northern 1966-74 (Consumer product)',
#   'Work Your Soul: Jamaican 60s & Northern 1966-74 (Consumer product)'),
#  ('Trojan Box Set: Jamaican Superstars (disc 1)',
#   'Trojan Box Set: Jamaican Superstars (disc 1)'),
#  ("Baby I'm a Want You (Jamaican mix) (Musical Recording)",
#   "Baby I'm a Want You (Jamaican mix) (Musical Recording)"),
#  ('m.0ly3sc5', "Baby I'm a Want You (Jamaican mix)"),
#  ('Bactris jamaicana', 'Bactris jamaicana'),
#  ('Run Tings (100% Jamaican dub plates) (Consumer product)',
#   'Run Tings (100% Jamaican dub plates) (Consumer product)'),
#  ('Jamaican Recordings (Consumer product)',
#   'Jamaican Recordings (Consumer product)'),
#  ('Bad Weed (extended Jamaican mix)', 'Bad Weed (extended Jamaican mix)'),
#  ('Disco Devil: The Jamaican Disco Mixes (Consumer product)',
#   'Disco Devil: The Jamaican Disco Mixes (Consumer product)'),
#  ('Jamaican food', 'Jamaican food'),
#  ('Dancehall 2: The Rise of Jamaican Dancehall Culture (Consumer product)',
#   'Dancehall 2: The Rise of Jamaican Dancehall Culture (Consumer product)'),
#  ('Jamaican fruit bat', 'Jamaican fruit bat'),
#  ('Trojan Jamaican Hits Box Set (disc 1)',
#   'Trojan Jamaican Hits Box Set (disc 1)'),
#  ('Trojan Jamaican Hits Box Set (disc 3)',
#   'Trojan Jamaican Hits Box Set (disc 3)'),
#  ('Bedasse & The Jamaican Calypsonians',
#   'Bedasse & The Jamaican Calypsonians'),
#  ('Jamaican Gold (Music Film)', 'Jamaican Gold (Music Film)'),
#  ('Rude Boy: The Jamaican Don', 'Rude Boy: The Jamaican Don'),
#  ('Believing identity : Pentecostalism and the mediation of Jamaican ethnicity and gender in England',
#   'Believing identity : Pentecostalism and the mediation of Jamaican ethnicity and gender in England'),
#  ("Ben Bowers & Bertie King's Royal Jamaicans",
#   "Ben Bowers & Bertie King's Royal Jamaicans"),
#  ('Bend Down Low (alternate Jamaican Soul mix) (Musical Recording)',
#   'Bend Down Low (alternate Jamaican Soul mix) (Musical Recording)'),
#  ('m.0ly8v8g', 'Bend Down Low (alternate Jamaican Soul mix)'),
#  ('Trojan Box Set: Jamaican Superstars (disc 2)',
#   'Trojan Box Set: Jamaican Superstars (disc 2)'),
#  ('Bibliography of Jamaican geology (Book Edition)',
#   'Bibliography of Jamaican geology (Book Edition)'),
#  ('Bibliography of Jamaican geology (Book)',
#   'Bibliography of Jamaican geology (Book)'),
#  ('Boogu Yagga Gal: Jamaican Mento (Musical Release)',
#   'Boogu Yagga Gal: Jamaican Mento (Musical Release)'),
#  ('Biologica Robotica (Jamaican Cyberturtle) (Canonical Version)',
#   'Biologica Robotica (Jamaican Cyberturtle) (Canonical Version)'),
#  ('m.0nqmql5', 'Biologica Robotica (Jamaican Cyberturtle)'),
#  ("Black Jamaicans' struggle against slavery",
#   "Black Jamaicans' struggle against slavery"),
#  ('Bloodlines - Jamaican Dub & Roots (Musical Album)',
#   'Bloodlines - Jamaican Dub & Roots (Musical Album)'),
#  ('Jamaican Order of Merit', 'Jamaican Order of Merit'),
#  ('Bob Marley & Toots Cover in Jamaican Ganja Field (Canonical Version)',
#   'Bob Marley & Toots Cover in Jamaican Ganja Field (Canonical Version)'),
#  ('m.0yc37zw', 'Bob Marley & Toots Cover in Jamaican Ganja Field'),
#  ('Carlos Malcolm & His Afro-Jamaican Rhythms',
#   'Carlos Malcolm & His Afro-Jamaican Rhythms'),
#  ('Easy Snapping: The Jamaican Chart Hits of 1960 (Consumer product)',
#   'Easy Snapping: The Jamaican Chart Hits of 1960 (Consumer product)'),
#  ('Boogu Yagga Gal: Jamaican Mento (Musical Album)',
#   'Boogu Yagga Gal: Jamaican Mento (Musical Album)'),
#  ('Jamaican Creole English Language', 'Jamaican Creole English Language'),
#  ('Born Jamaican (Musical Recording)', 'Born Jamaican (Musical Recording)'),
#  ('m.0l18017', 'Born Jamaican'),
#  ('Born Jamaicans', 'Born Jamaicans'),
#  ("Born fi' dead: a journey through the Jamaican posse underworld",
#   "Born fi' dead: a journey through the Jamaican posse underworld"),
#  ('British Jamaican', 'British Jamaican'),
#  ('Jamaican English', 'Jamaican English'),
#  ("Jamaica Funk - Original Jamaican Funk and Soul 45's (Consumer product)",
#   "Jamaica Funk - Original Jamaican Funk and Soul 45's (Consumer product)"),
#  ("Busha Browne's indispensable compendium of traditional Jamaican cookery (Book Edition)",
#   "Busha Browne's indispensable compendium of traditional Jamaican cookery (Book Edition)"),
#  ("Busha Browne's indispensable compendium of traditional Jamaican cookery (Book)",
#   "Busha Browne's indispensable compendium of traditional Jamaican cookery (Book)"),
#  ('Jamaican folk music', 'Jamaican folk music'),
#  ('Canadianizing Jamaican patois', 'Canadianizing Jamaican patois'),
#  ('Carl Stone on Jamaican politics, economics & society',
#   'Carl Stone on Jamaican politics, economics & society'),
#  ('Jamaicans for Justice', 'Jamaicans for Justice'),
#  ('Chances Are (alternate Jamaican Soul mix) (Musical Recording)',
#   'Chances Are (alternate Jamaican Soul mix) (Musical Recording)'),
#  ('m.0ly8v64', 'Chances Are (alternate Jamaican Soul mix)'),
#  ('Jamaicanization (Consumer product)', 'Jamaicanization (Consumer product)'),
#  ('Chinese Jamaicans', 'Chinese Jamaicans'),
#  ('Classic Jamaican Cooking', 'Classic Jamaican Cooking'),
#  ('Codeswitching on the web : English and Jamaican Creole in e-mail communication',
#   'Codeswitching on the web : English and Jamaican Creole in e-mail communication'),
#  ('The General Da Jamaican Boy', 'The General Da Jamaican Boy'),
#  ('m.0rs6vlc', 'Come Along/Jamaican Collie (extended mix)'),
#  ('m.0rtt7yj', 'Come Along/Jamaican Collie (extended mix)'),
#  ('Jamaica: Anthology of Jamaican Music (Musical Release)',
#   'Jamaica: Anthology of Jamaican Music (Musical Release)'),
#  ('Creole languages of the Caribbean Area : a comparison of the grammar of Jamaican Creole with those of the Creole languages of Haiti, the Antilles, the Guianas, the Virgin Islands, and the Dutch West Indies',
#   'Creole languages of the Caribbean Area : a comparison of the grammar of Jamaican Creole with those of the Creole languages of Haiti, the Antilles, the Guianas, the Virgin Islands, and the Dutch West Indies'),
#  ('Dancehall 2: The Rise of Jamaican Dancehall Culture (Musical Album)',
#   'Dancehall 2: The Rise of Jamaican Dancehall Culture (Musical Album)'),
#  ('Dancehall: The Rise of Jamaican Dancehall Culture (Musical Album)',
#   'Dancehall: The Rise of Jamaican Dancehall Culture (Musical Album)'),
#  ('Jamaican Celebration (Compact Disc Musical Release)',
#   'Jamaican Celebration (Compact Disc Musical Release)'),
#  ('Jamaican Heroes (Musical Release)', 'Jamaican Heroes (Musical Release)'),
#  ('Defining Jamaican fiction', 'Defining Jamaican fiction'),
#  ('Defining Jamaican fiction : marronage and the discourse of survival',
#   'Defining Jamaican fiction : marronage and the discourse of survival'),
#  ('Democratic socialism and the capitalist class : an analysis of the relation between Jamaican business and the PNP government',
#   'Democratic socialism and the capitalist class : an analysis of the relation between Jamaican business and the PNP government'),
#  ('Diplomats- Jamaican Joint (Canonical Version)',
#   'Diplomats- Jamaican Joint (Canonical Version)'),
#  ('m.0lg0qnz', 'Diplomats- Jamaican Joint'),
#  ('Disco Devil: The Jamaican Disco Mixes (Musical Album)',
#   'Disco Devil: The Jamaican Disco Mixes (Musical Album)'),
#  ('Distinguished Jamaican English (Musical Recording)',
#   'Distinguished Jamaican English (Musical Recording)'),
#  ('Distinguished Jamaican English (The Herbaliser Remix Instrumental) (Musical Recording)',
#   'Distinguished Jamaican English (The Herbaliser Remix Instrumental) (Musical Recording)'),
#  ('m.0smhm7j',
#   'Distinguished Jamaican English (The Herbaliser Remix Instrumental)'),
#  ('Distinguished Jamaican English (The Herbaliser remix instrumental) (Musical Recording)',
#   'Distinguished Jamaican English (The Herbaliser remix instrumental) (Musical Recording)'),
#  ('Time to Build / Distinguished Jamaican English',
#   'Time to Build / Distinguished Jamaican English'),
#  ('m.0n10zny',
#   'Distinguished Jamaican English (The Herbaliser remix instrumental)'),
#  ('Distinguished Jamaican English (The Herbaliser remix)',
#   'Distinguished Jamaican English (The Herbaliser remix)'),
#  ('Distinguished Jamaican English (The Herbaliser remix) (feat. Phi-Life Cypher)',
#   'Distinguished Jamaican English (The Herbaliser remix) (feat. Phi-Life Cypher)'),
#  ('Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix) (Musical Recording)',
#   'Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix) (Musical Recording)'),
#  ('m.0skp6mv',
#   'Distinguished Jamaican English (feat. Phi Life Cypher) (The Herbaliser remix)'),
#  ('Distinguished Jamaican English (feat. Phi-Life Cypher) (Musical Recording)',
#   'Distinguished Jamaican English (feat. Phi-Life Cypher) (Musical Recording)'),
#  ('m.0q9rf_9', 'Distinguished Jamaican English (feat. Phi-Life Cypher)'),
#  ('m.0lsyw5q', 'Distinguished Jamaican English'),
#  ('Distinguished Jamaican English Remix (Instrumental) (Musical Recording)',
#   'Distinguished Jamaican English Remix (Instrumental) (Musical Recording)'),
#  ('Distinguished Jamaican English Remix (feat. Phi Life Cypher) (Canonical Version)',
#   'Distinguished Jamaican English Remix (feat. Phi Life Cypher) (Canonical Version)'),
#  ('m.0l6dxbz', 'Distinguished Jamaican English Remix (Instrumental)'),
#  ('m.0l6dxbq', 'Distinguished Jamaican English Remix (feat. Phi Life Cypher)'),
#  ('Jamaican Rock Steady Party (Compact Disc Musical Release)',
#   'Jamaican Rock Steady Party (Compact Disc Musical Release)'),
#  ("Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN) (Musical Recording)",
#   "Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN) (Musical Recording)"),
#  ('m.0m9p0yw', "Don't Feel No Way (Jamaican Dub Mix) (featuring BOY-KEN)"),
#  ("Don't Stop the Music (Smooth Jamaican mix) (Musical Recording)",
#   "Don't Stop the Music (Smooth Jamaican mix) (Musical Recording)"),
#  ('m.0mj_0mz', "Don't Stop the Music (Smooth Jamaican mix)"),
#  ('The Jamaican Calypsonians', 'The Jamaican Calypsonians'),
#  ('Jamaican Guys', 'Jamaican Guys'),
#  ('Drumblair: Memories of a Jamaican Childhood',
#   'Drumblair: Memories of a Jamaican Childhood'),
#  ('Jamaican Recordings (Record label)', 'Jamaican Recordings (Record label)'),
#  ('Easy Snapping: The Jamaican Chart Hits of 1960 (Musical Album)',
#   'Easy Snapping: The Jamaican Chart Hits of 1960 (Musical Album)'),
#  ('En Aquel Hotel Jamaicano (Musical Recording)',
#   'En Aquel Hotel Jamaicano (Musical Recording)'),
#  ('m.0kzqvxp', 'En Aquel Hotel Jamaicano'),
#  ('m.0mgkk6r', 'En Aquel Hotel Jamaicano'),
#  ('Encyclopedia of Jamaican heritage', 'Encyclopedia of Jamaican heritage'),
#  ('Encyclopedia of Jamaican heritage (Book Edition)',
#   'Encyclopedia of Jamaican heritage (Book Edition)'),
#  ('Envisioning Caribbean futures : Jamaican perspectives',
#   'Envisioning Caribbean futures : Jamaican perspectives'),
#  ('Episode 6: Jamaican', 'Episode 6: Jamaican'),
#  ('Mr. T-Bone and his Jamaican Liberation Orchestra',
#   'Mr. T-Bone and his Jamaican Liberation Orchestra'),
#  ("Fakin' Jamaican (Musical Recording) #1",
#   "Fakin' Jamaican (Musical Recording) #1"),
#  ("Fakin' Jamaican (Musical Recording) #3",
#   "Fakin' Jamaican (Musical Recording) #3"),
#  ("Fakin' Jamaican (Musical Recording) #2",
#   "Fakin' Jamaican (Musical Recording) #2"),
#  ('m.0kn5xvs', "Fakin' Jamaican"),
#  ('m.0ktp5k_', "Fakin' Jamaican"),
#  ('m.0n85qvf', "Fakin' Jamaican"),
#  ("Fire Water Burn (Jim Makin' Jamaican mix) (Musical Recording)",
#   "Fire Water Burn (Jim Makin' Jamaican mix) (Musical Recording)"),
#  ('m.0zvsgxn', "Fire Water Burn (Jim Makin' Jamaican mix)"),
#  ('Fire Water Burn (Jim Makin’ Jamaican Mix)',
#   'Fire Water Burn (Jim Makin’ Jamaican Mix)'),
#  ('m.0khzfvc', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('m.0kmrql8', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('m.0mc1_lf', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('m.0mszkxx', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('m.0mvhp32', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('m.0rv31k7', 'Fire Water Burn (Jim Makin’ Jamaican mix)'),
#  ('Jamaican Amber Rum', 'Jamaican Amber Rum'),
#  ('Jamaican-Inspired Bedroom', 'Jamaican-Inspired Bedroom'),
#  ('Folklore from contemporary Jamaicans (Book Edition)',
#   'Folklore from contemporary Jamaicans (Book Edition)'),
#  ('Folklore from contemporary Jamaicans (Book)',
#   'Folklore from contemporary Jamaicans (Book)'),
#  ('Girl From Ipanema (Jamaican mix) (Musical Recording)',
#   'Girl From Ipanema (Jamaican mix) (Musical Recording)'),
#  ('m.0ly3s7v', 'Girl From Ipanema (Jamaican mix)'),
#  ('Growing Up Jamaican', 'Growing Up Jamaican'),
#  ('Help Me Make It Through the Night (Jamaican mix) (Musical Recording)',
#   'Help Me Make It Through the Night (Jamaican mix) (Musical Recording)'),
#  ('m.0ly3scm', 'Help Me Make It Through the Night (Jamaican mix)'),
#  ("High Plains Drifter: Jamaican 45's 1968-73 (Musical Album)",
#   "High Plains Drifter: Jamaican 45's 1968-73 (Musical Album)"),
#  ('High School / Jamaican Boa (Musical Recording)',
#   'High School / Jamaican Boa (Musical Recording)'),
#  ('High School / Jamaican Boa (interlude) (Musical Recording)',
#   'High School / Jamaican Boa (interlude) (Musical Recording)'),
#  ('m.0mqjxgz', 'High School / Jamaican Boa (interlude)'),
#  ('m.0msxg7b', 'High School / Jamaican Boa (interlude)'),
#  ('m.0rrrb3m', 'High School / Jamaican Boa'),
#  ('Jamaican iguana', 'Jamaican iguana'),
#  ('Hot Jamaican Mixture (Musical Album)',
#   'Hot Jamaican Mixture (Musical Album)'),
#  ('Hot Jamaican Mixture (Musical Release)',
#   'Hot Jamaican Mixture (Musical Release)'),
#  ('How to speak Jamaican? (Book Edition)',
#   'How to speak Jamaican? (Book Edition)'),
#  ('How to speak Jamaican? (Book)', 'How to speak Jamaican? (Book)'),
#  ('Ska Boogie: Jamaican R&B, the Dawn of Ska (Compact Disc Musical Release)',
#   'Ska Boogie: Jamaican R&B, the Dawn of Ska (Compact Disc Musical Release)'),
#  ('I Love The Piano / Jamaican Style (Gramophone record Musical Release)',
#   'I Love The Piano / Jamaican Style (Gramophone record Musical Release)'),
#  ('I Love The Piano / Jamaican Style (Musical Album)',
#   'I Love The Piano / Jamaican Style (Musical Album)'),
#  ('Ilex jamaicana', 'Ilex jamaicana'),
#  ('Irie Jamaican Girl (Canonical Version)',
#   'Irie Jamaican Girl (Canonical Version)'),
#  ('m.0nr6l2j', 'Irie Jamaican Girl'),
#  ('JAMAICAN TEAS LTD Common Stock', 'JAMAICAN TEAS LTD Common Stock'),
#  ('Jamaican Teas', 'Jamaican Teas'),
#  ('JAMAICAN WARRIORS: REGGAE, ROOTS & CULTURE',
#   'JAMAICAN WARRIORS: REGGAE, ROOTS & CULTURE'),
#  ('Jamaican Warriors', 'Jamaican Warriors'),
#  ('Jah music: the evolution of the popular Jamaican song',
#   'Jah music: the evolution of the popular Jamaican song'),
#  ('Jamaican dollar', 'Jamaican dollar'),
#  ('Jamaica (Jamaican Getaway)', 'Jamaica (Jamaican Getaway)'),
#  ('Jamaican Farewell (Musical Recording) #5',
#   'Jamaican Farewell (Musical Recording) #5'),
#  ("Jamaica Funk - Original Jamaican Funk and Soul 45's (Musical Album)",
#   "Jamaica Funk - Original Jamaican Funk and Soul 45's (Musical Album)"),
#  ('Jamaica farewell: Jamaican migrants in London',
#   'Jamaica farewell: Jamaican migrants in London'),
#  ('Jamaican Heroes (Musical Recording) #2',
#   'Jamaican Heroes (Musical Recording) #2'),
#  ('Jamaica: Anthology of Jamaican Music (Musical Album)',
#   'Jamaica: Anthology of Jamaican Music (Musical Album)'),
#  ('Jamaican (Musical Recording) #1', 'Jamaican (Musical Recording) #1'),
#  ('Jamaican (Musical Recording) #2', 'Jamaican (Musical Recording) #2'),
#  ('Jamaican (Musical Recording) #3', 'Jamaican (Musical Recording) #3'),
#  ('Jamaican (Punk Reggae Party) (Canonical Version)',
#   'Jamaican (Punk Reggae Party) (Canonical Version)'),
#  ('m.0kkh6vs', 'Jamaican (Punk Reggae Party)'),
#  ('Jamaican (TV Episode) #4', 'Jamaican (TV Episode) #4'),
#  ('Jamaican (TV Episode) #5', 'Jamaican (TV Episode) #5'),
#  ('Jamaican Australian', 'Jamaican Australian'),
#  ('Jamaican Bacon Experience', 'Jamaican Bacon Experience'),
#  ('Jamaican Badboy (Canonical Version)',
#   'Jamaican Badboy (Canonical Version)'),
#  ('m.0nsglc7', 'Jamaican Badboy'),
#  ('Jamaican Baion (Canonical Version)', 'Jamaican Baion (Canonical Version)'),
#  ('m.0n17hm7', 'Jamaican Baion'),
#  ('Jamaican Barbeque (Canonical Version)',
#   'Jamaican Barbeque (Canonical Version)'),
#  ('m.0xhj4nc', 'Jamaican Barbeque'),
#  ('Jamaican Beat (Musical Album)', 'Jamaican Beat (Musical Album)'),
#  ('Jamaican Becard', 'Jamaican Becard'),
#  ('Jamaican Blackbird', 'Jamaican Blackbird'),
#  ('Jamaican Blowhole (Musical Recording)',
#   'Jamaican Blowhole (Musical Recording)'),
#  ('m.0my26l_', 'Jamaican Blowhole'),
#  ('Jamaican Bobsledding Chant', 'Jamaican Bobsledding Chant'),
#  ('m.0ktn__k', 'Jamaican Bobsledding Chant'),
#  ('m.0l0nnxx', 'Jamaican Bobsledding Chant'),
#  ('m.0mpwwfn', 'Jamaican Bobsledding Chant'),
#  ('Jamaican Bobsleigh Federation', 'Jamaican Bobsleigh Federation'),
#  ('Jamaican Born and Bred (Musical Recording)',
#   'Jamaican Born and Bred (Musical Recording)'),
#  ('m.0mdch7r', 'Jamaican Born and Bred'),
#  ('Jamaican Boy (Musical Recording) #1',
#   'Jamaican Boy (Musical Recording) #1'),
#  ('Jamaican Boy (Musical Recording) #2',
#   'Jamaican Boy (Musical Recording) #2'),
#  ('Jamaican Boy (Musical Recording) #3',
#   'Jamaican Boy (Musical Recording) #3'),
#  ('Jamaican Boy (Musical Recording) #4',
#   'Jamaican Boy (Musical Recording) #4'),
#  ('Jamaican Boy (Musical Recording) #5',
#   'Jamaican Boy (Musical Recording) #5'),
#  ('Jamaican Boy (Musical Recording) #6',
#   'Jamaican Boy (Musical Recording) #6'),
#  ('m.0ldch5l', 'Jamaican Boy'),
#  ('m.0m1td9n', 'Jamaican Boy'),
#  ('m.0m1tjmc', 'Jamaican Boy'),
#  ('m.0m85q6g', 'Jamaican Boy'),
#  ('m.0mjtq04', 'Jamaican Boy'),
#  ('m.0myvxqp', 'Jamaican Boy'),
#  ('Jamaican Breeze (Musical Recording)',
#   'Jamaican Breeze (Musical Recording)'),
#  ('m.0lyj7xn', 'Jamaican Breeze'),
#  ('Jamaican Bye-Bye (Canonical Version)',
#   'Jamaican Bye-Bye (Canonical Version)'),
#  ('m.0qg8p9v', 'Jamaican Bye-Bye'),
#  ('Jamaican Calley (Version)', 'Jamaican Calley (Version)'),
#  ('Jamaican Calley (version)', 'Jamaican Calley (version)'),
#  ('Jamaican Colley (version) (Musical Recording) #1',
#   'Jamaican Colley (version) (Musical Recording) #1'),
#  ('Jamaican Callie (version) (Musical Recording)',
#   'Jamaican Callie (version) (Musical Recording)'),
#  ('m.0kt_gq5', 'Jamaican Callie (version)'),
#  ('m.0lc_gfk', 'Jamaican Callie (version)'),
#  ('Jamaican Canadian', 'Jamaican Canadian'),
#  ('Jamaican Caracara', 'Jamaican Caracara'),
#  ('Jamaican Carnival (Musical Recording)',
#   'Jamaican Carnival (Musical Recording)'),
#  ('m.0lzdnnj', 'Jamaican Carnival'),
#  ('Jamaican Carnival, Part 1 (Canonical Version)',
#   'Jamaican Carnival, Part 1 (Canonical Version)'),
#  ('m.0yc_vr5', 'Jamaican Carnival, Part 1'),
#  ('Jamaican Carnival, Part 2 (Canonical Version)',
#   'Jamaican Carnival, Part 2 (Canonical Version)'),
#  ('m.0ybpy5q', 'Jamaican Carnival, Part 2'),
#  ('Jamaican Caves Organisation', 'Jamaican Caves Organisation'),
#  ('Jamaican Celebration (Canonical Version)',
#   'Jamaican Celebration (Canonical Version)'),
#  ('Jamaican Celebration (Musical Album)',
#   'Jamaican Celebration (Musical Album)'),
#  ('m.0mxpv30', 'Jamaican Celebration'),
#  ('Jamaican Child (Musical Recording) #1',
#   'Jamaican Child (Musical Recording) #1'),
#  ('Jamaican Child (Musical Recording) #2',
#   'Jamaican Child (Musical Recording) #2'),
#  ('m.0ly05q2', 'Jamaican Child'),
#  ('m.0md3m94', 'Jamaican Child'),
#  ('Jamaican Childhood (Musical Recording)',
#   'Jamaican Childhood (Musical Recording)'),
#  ('m.0l7j_n2', 'Jamaican Childhood'),
#  ('Jamaican Clinic (Canonical Version)',
#   'Jamaican Clinic (Canonical Version)'),
#  ('m.0zr8dfc', 'Jamaican Clinic'),
#  ('Jamaican Coffee Farmer', 'Jamaican Coffee Farmer'),
#  ('Jamaican Colley (Musical Recording)',
#   'Jamaican Colley (Musical Recording)'),
#  ('Jamaican Colley (Version) (Musical Recording)',
#   'Jamaican Colley (Version) (Musical Recording)'),
#  ('m.0m51jr5', 'Jamaican Colley (Version)'),
#  ('m.0ydbry5', 'Jamaican Colley'),
#  ('Jamaican Colley (version) (Musical Recording) #2',
#   'Jamaican Colley (version) (Musical Recording) #2'),
#  ('m.0l5bgvs', 'Jamaican Colley (version)'),
#  ('m.0l7np6b', 'Jamaican Colley (version)'),
#  ('m.0m56mw_', 'Jamaican Colley (version)'),
#  ('Jamaican Colley Version (Musical Recording) #1',
#   'Jamaican Colley Version (Musical Recording) #1'),
#  ('Jamaican Colley Version (Musical Recording) #2',
#   'Jamaican Colley Version (Musical Recording) #2'),
#  ('m.0mh9173', 'Jamaican Colley Version'),
#  ('m.0mmp3zs', 'Jamaican Colley Version'),
#  ('Jamaican Collie (Musical Recording) #1',
#   'Jamaican Collie (Musical Recording) #1'),
#  ('Jamaican Collie (Musical Recording) #2',
#   'Jamaican Collie (Musical Recording) #2'),
#  ('Jamaican Collie (Musical Recording) #3',
#   'Jamaican Collie (Musical Recording) #3'),
#  ('Jamaican Collie (Musical Recording) #4',
#   'Jamaican Collie (Musical Recording) #4'),
#  ('Jamaican Collie (Musical Recording) #5',
#   'Jamaican Collie (Musical Recording) #5'),
#  ('m.0lvsyf7', 'Jamaican Collie'),
#  ('m.0lyr7sl', 'Jamaican Collie'),
#  ('m.0lyvdj7', 'Jamaican Collie'),
#  ('m.0mlk6xt', 'Jamaican Collie'),
#  ('m.0mm86qc', 'Jamaican Collie'),
#  ('m.0rt4lt3', 'Jamaican Collie'),
#  ('Jamaican Country Sign Language', 'Jamaican Country Sign Language'),
#  ('Jamaican Creole', 'Jamaican Creole'),
#  ('Jamaican Creole an historical introduction to Jamaican Creole',
#   'Jamaican Creole an historical introduction to Jamaican Creole'),
#  ('Jamaican Crow', 'Jamaican Crow'),
#  ('Jamaican Cyberturtle (Canonical Version)',
#   'Jamaican Cyberturtle (Canonical Version)'),
#  ('m.0nqmpqx', 'Jamaican Cyberturtle'),
#  ('m.0nsrt7j', 'Jamaican Cyberturtle'),
#  ('Jamaican Dance Mania (Musical Recording)',
#   'Jamaican Dance Mania (Musical Recording)'),
#  ('m.0myzcxq', 'Jamaican Dance Mania'),
#  ('Jamaican Day Dream (Canonical Version)',
#   'Jamaican Day Dream (Canonical Version)'),
#  ('m.0x1bssp', 'Jamaican Day Dream'),
#  ('Jamaican Diplomocracy (Canonical Version)',
#   'Jamaican Diplomocracy (Canonical Version)'),
#  ('m.0llbkxs', 'Jamaican Diplomocracy'),
#  ('Jamaican Dollar (Canonical Version)',
#   'Jamaican Dollar (Canonical Version)'),
#  ('Jamaican Dollar (Musical Recording)',
#   'Jamaican Dollar (Musical Recording)'),
#  ('m.0nt5vnt', 'Jamaican Dollar'),
#  ('m.0w0jppl', 'Jamaican Dollar'),
#  ('Jamaican Dollars (Musical Recording)',
#   'Jamaican Dollars (Musical Recording)'),
#  ('m.0lgx7yt', 'Jamaican Dollars'),
#  ('Jamaican Dream (Canonical Version)', 'Jamaican Dream (Canonical Version)'),
#  ('m.0lxdd4f', 'Jamaican Dream'),
#  ('Jamaican Drums (Musical Recording)', 'Jamaican Drums (Musical Recording)'),
#  ('m.0m6fd6g', 'Jamaican Drums'),
#  ('Jamaican Dub', 'Jamaican Dub'),
#  ('Jamaican Dub (Musical Recording) #1',
#   'Jamaican Dub (Musical Recording) #1'),
#  ('m.0kz0vr7', 'Jamaican Dub'),
#  ('m.0lw343l', 'Jamaican Dub'),
#  ('Jamaican Dub Style (Musical Recording)',
#   'Jamaican Dub Style (Musical Recording)'),
#  ('m.0myzcxh', 'Jamaican Dub Style'),
#  ('Jamaican Dust (Musical Recording)', 'Jamaican Dust (Musical Recording)'),
#  ('m.0mb83yy', 'Jamaican Dust'),
#  ('Jamaican E.T.', 'Jamaican E.T.'),
#  ('Jamaican E.T. (Musical Recording) #1',
#   'Jamaican E.T. (Musical Recording) #1'),
#  ('Jamaican E.T. (Musical Recording) #2',
#   'Jamaican E.T. (Musical Recording) #2'),
#  ('Jamaican E.T. (Musical Release)', 'Jamaican E.T. (Musical Release)'),
#  ('m.0l82tv8', 'Jamaican E.T.'),
#  ('m.0mzx97z', 'Jamaican E.T.'),
#  ('m.0n09rs2', 'Jamaican E.T.'),
#  ('Jamaican Elaenia', 'Jamaican Elaenia'),
#  ('Jamaican Euphonia', 'Jamaican Euphonia'),
#  ('Jamaican Farewell', 'Jamaican Farewell'),
#  ('Jamaican Farewell (Canonical Version) #1',
#   'Jamaican Farewell (Canonical Version) #1'),
#  ('Jamaican Farewell (Canonical Version) #3',
#   'Jamaican Farewell (Canonical Version) #3'),
#  ('Jamaican Farewell (Musical Recording) #2',
#   'Jamaican Farewell (Musical Recording) #2'),
#  ('Jamaican Farewell (Musical Recording) #4',
#   'Jamaican Farewell (Musical Recording) #4'),
#  ('m.0lws6c5', 'Jamaican Farewell'),
#  ('m.0m3x4p6', 'Jamaican Farewell'),
#  ('m.0mvqj85', 'Jamaican Farewell'),
#  ('m.0mz55jc', 'Jamaican Farewell'),
#  ('m.0n0ll33', 'Jamaican Farewell'),
#  ('m.0y8y_jy', 'Jamaican Farewell'),
#  ('Jamaican Funk (Canonical Version)', 'Jamaican Funk (Canonical Version)'),
#  ('m.0_j1ph4', 'Jamaican Funk'),
#  ('Jamaican Funk—Canadian Style', 'Jamaican Funk—Canadian Style'),
#  ('Jamaican Funk—Canadian Style (Canonical Version)',
#   'Jamaican Funk—Canadian Style (Canonical Version)'),
#  ('m.0_jrqh4', 'Jamaican Funk—Canadian Style'),
#  ('Jamaican Gangs, Guns and Ganja (TV Episode) #1',
#   'Jamaican Gangs, Guns and Ganja (TV Episode) #1'),
#  ('Jamaican Gangs, Guns and Ganja (TV Episode) #2',
#   'Jamaican Gangs, Guns and Ganja (TV Episode) #2'),
#  ('Jamaican Gangster', 'Jamaican Gangster'),
#  ('Jamaican Georgian architecture', 'Jamaican Georgian architecture'),
#  ('Jamaican Getaway (Musical Recording)',
#   'Jamaican Getaway (Musical Recording)'),
#  ('m.0kksr5_', 'Jamaican Getaway'),
#  ('Jamaican Girl (Canonical Version) #3',
#   'Jamaican Girl (Canonical Version) #3'),
#  ('Jamaican Girl (Canonical Version) #4',
#   'Jamaican Girl (Canonical Version) #4'),
#  ('Jamaican Girl (Musical Recording) #1',
#   'Jamaican Girl (Musical Recording) #1'),
#  ('Jamaican Girl (Musical Recording) #2',
#   'Jamaican Girl (Musical Recording) #2'),
#  ('Jamaican Girl (Musical Recording) #5',
#   'Jamaican Girl (Musical Recording) #5'),
#  ('Jamaican Girl (explicit) (Musical Recording)',
#   'Jamaican Girl (explicit) (Musical Recording)'),
#  ('m.0n336wk', 'Jamaican Girl (explicit)'),
#  ('m.0kr_98v', 'Jamaican Girl'),
#  ('m.0kwlx68', 'Jamaican Girl'),
#  ('m.0l5xc58', 'Jamaican Girl'),
#  ('m.0llcx8d', 'Jamaican Girl'),
#  ('m.0qg6x8j', 'Jamaican Girl'),
#  ('Jamaican Girl Style (Canonical Version)',
#   'Jamaican Girl Style (Canonical Version)'),
#  ('m.0xj354t', 'Jamaican Girl Style'),
#  ('Jamaican Girls (Canonical Version)', 'Jamaican Girls (Canonical Version)'),
#  ('Jamaican Girls (Musical Recording) #1',
#   'Jamaican Girls (Musical Recording) #1'),
#  ('Jamaican Girls (Musical Recording) #2',
#   'Jamaican Girls (Musical Recording) #2'),
#  ('m.0kkhs0t', 'Jamaican Girls'),
#  ('m.0mqgxbm', 'Jamaican Girls'),
#  ('m.0yb5ynl', 'Jamaican Girls'),
#  ('Jamaican Gold', 'Jamaican Gold'),
#  ('Jamaican Gold (Canonical Version)', 'Jamaican Gold (Canonical Version)'),
#  ('m.0sk04xm', 'Jamaican Gold'),
#  ('Jamaican Grass', 'Jamaican Grass'),
#  ('m.0kllr3n', 'Jamaican Grass'),
#  ('m.0sl86mp', 'Jamaican Grass'),
#  ('Jamaican Gun Sling (Musical Recording)',
#   'Jamaican Gun Sling (Musical Recording)'),
#  ('m.0m8f4h7', 'Jamaican Gun Sling'),
#  ('Jamaican Hairdresser', 'Jamaican Hairdresser'),
#  ('Jamaican Heroes', 'Jamaican Heroes'),
#  ('Jamaican Heroes (Musical Recording) #1',
#   'Jamaican Heroes (Musical Recording) #1'),
#  ('m.0ljhm63', 'Jamaican Heroes'),
#  ('m.0lk_9hv', 'Jamaican Heroes'),
#  ('m.0lrzjsn', 'Jamaican Heroes'),
#  ('m.0m6307k', 'Jamaican Heroes'),
#  ('Jamaican History (version) (Musical Recording)',
#   'Jamaican History (version) (Musical Recording)'),
#  ('m.0l8mmr8', 'Jamaican History (version)'),
#  ('Jamaican Holiday (Canonical Version)',
#   'Jamaican Holiday (Canonical Version)'),
#  ('m.0ltktyg', 'Jamaican Holiday'),
#  ('Jamaican Homecoming (Composition)', 'Jamaican Homecoming (Composition)'),
#  ('Jamaican Homecoming (Musical Recording)',
#   'Jamaican Homecoming (Musical Recording)'),
#  ('m.0lrxby4', 'Jamaican Homecoming'),
#  ('Jamaican House Revenge (Canonical Version)',
#   'Jamaican House Revenge (Canonical Version)'),
#  ('m.0_jq70b', 'Jamaican House Revenge'),
#  ('Jamaican House of Representatives', 'Jamaican House of Representatives'),
#  ('Jamaican Ibis', 'Jamaican Ibis'),
#  ('Jamaican In New York (Musical Recording) #2',
#   'Jamaican In New York (Musical Recording) #2'),
#  ('Jamaican In New York (Musical Recording) #3',
#   'Jamaican In New York (Musical Recording) #3'),
#  ('Jamaican In New York (Musical Recording) #4',
#   'Jamaican In New York (Musical Recording) #4'),
#  ('m.0kw7md2', 'Jamaican In New York'),
#  ('m.0kww9sd', 'Jamaican In New York'),
#  ('m.0lmdffd', 'Jamaican In New York'),
#  ('m.0lqmvdt', 'Jamaican In New York'),
#  ('m.0ltl09m', 'Jamaican In New York'),
#  ('m.0qd_1qq', 'Jamaican In New York'),
#  ('Jamaican Jam (Musical Recording)', 'Jamaican Jam (Musical Recording)'),
#  ('m.0mq3g1f', 'Jamaican Jam'),
#  ('Jamaican Jamboree (Canonical Version)',
#   'Jamaican Jamboree (Canonical Version)'),
#  ('m.0xdgxpj', 'Jamaican Jamboree'),
#  ("Jamaican Jammin' (Canonical Version)",
#   "Jamaican Jammin' (Canonical Version)"),
#  ('m.0sjmlg6', "Jamaican Jammin'"),
#  ('Jamaican Jig (Abashanti remix) (Musical Recording)',
#   'Jamaican Jig (Abashanti remix) (Musical Recording)'),
#  ('Jamaican Jig (Musical Recording)', 'Jamaican Jig (Musical Recording)'),
#  ('m.0kmx_tq', 'Jamaican Jig (Abashanti remix)'),
#  ('m.0kt97zg', 'Jamaican Jig'),
#  ('Jamaican Jigglers (Musical Recording)',
#   'Jamaican Jigglers (Musical Recording)'),
#  ('m.0l5_ffx', 'Jamaican Jigglers'),
#  ("Jamaican Joint (feat. Cam'ron and Juelz Santana) (Musical Recording)",
#   "Jamaican Joint (feat. Cam'ron and Juelz Santana) (Musical Recording)"),
#  ('m.0n87f1b', "Jamaican Joint (feat. Cam'ron and Juelz Santana)"),
#  ('Jamaican Lady', 'Jamaican Lady'),
#  ('Jamaican Lady (Canonical Version)', 'Jamaican Lady (Canonical Version)'),
#  ('Jamaican Lady (Musical Recording) #1',
#   'Jamaican Lady (Musical Recording) #1'),
#  ('Jamaican Lady (interlude) (Musical Recording) #3',
#   'Jamaican Lady (interlude) (Musical Recording) #3'),
#  ('Jamaican Lady (interlude) (Musical Recording) #1',
#   'Jamaican Lady (interlude) (Musical Recording) #1'),
#  ('Jamaican Lady (interlude) (Musical Recording) #2',
#   'Jamaican Lady (interlude) (Musical Recording) #2'),
#  ('Jamaican Lady (interlude) (Musical Recording) #4',
#   'Jamaican Lady (interlude) (Musical Recording) #4'),
#  ('m.0mfjqyz', 'Jamaican Lady (interlude)'),
#  ('m.0mfjs2_', 'Jamaican Lady (interlude)'),
#  ('m.0mfjs5y', 'Jamaican Lady (interlude)'),
#  ('m.0mfjscf', 'Jamaican Lady (interlude)'),
#  ('m.0mfjr_l', 'Jamaican Lady'),
#  ('m.0mj4fn_', 'Jamaican Lady'),
#  ('m.0st_4d6', 'Jamaican Lady'),
#  ('Jamaican Lizard Cuckoo', 'Jamaican Lizard Cuckoo'),
#  ('Jamaican Luau', 'Jamaican Luau'),
#  ('m.0mw8g57', 'Jamaican Luau'),
#  ('Jamaican Mango', 'Jamaican Mango'),
#  ('Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases) (Canonical Version)',
#   'Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases) (Canonical Version)'),
#  ('m.0xb7sb3',
#   'Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases)'),
#  ('m.0yc0lx8',
#   'Jamaican Market Place (Atelier Musca Latino Americana feat. conductor: Cristian Grases)'),
#  ('Jamaican Market Place (Canonical Version) #1',
#   'Jamaican Market Place (Canonical Version) #1'),
#  ('Jamaican Market Place (Canonical Version) #2',
#   'Jamaican Market Place (Canonical Version) #2'),
#  ('Jamaican Market Place (Musical Recording)',
#   'Jamaican Market Place (Musical Recording)'),
#  ('m.0kwdx6c', 'Jamaican Market Place'),
#  ('m.0mq69j0', 'Jamaican Market Place'),
#  ('m.0y9g0x8', 'Jamaican Market Place'),
#  ('Jamaican Marketplace (Musical Recording)',
#   'Jamaican Marketplace (Musical Recording)'),
#  ('m.0mxj6_f', 'Jamaican Marketplace'),
#  ('Jamaican Maroon spirit-possession language',
#   'Jamaican Maroon spirit-possession language'),
#  ('Jamaican Me Crazy (Canonical Version)',
#   'Jamaican Me Crazy (Canonical Version)'),
#  ('Jamaican Me Crazy (Musical Recording)',
#   'Jamaican Me Crazy (Musical Recording)'),
#  ('Jamaican Me Crazy (TV Episode) #1', 'Jamaican Me Crazy (TV Episode) #1'),
#  ('Jamaican Me Crazy (TV Episode) #2', 'Jamaican Me Crazy (TV Episode) #2'),
#  ('Jamaican Me Crazy (TV Episode) #3', 'Jamaican Me Crazy (TV Episode) #3'),
#  ('m.0l_gvgl', 'Jamaican Me Crazy'),
#  ('m.0mfmy00', 'Jamaican Me Crazy'),
#  ('Jamaican Me Hungry', 'Jamaican Me Hungry'),
#  ('Jamaican Medley: Kingston Town / Banana Boat (Musical Recording)',
#   'Jamaican Medley: Kingston Town / Banana Boat (Musical Recording)'),
#  ('m.0mj108x', 'Jamaican Medley: Kingston Town / Banana Boat'),
#  ('Jamaican Mess Around (Canonical Version)',
#   'Jamaican Mess Around (Canonical Version)'),
#  ('m.0ls3dg3', 'Jamaican Mess Around'),
#  ('Jamaican Midnight', 'Jamaican Midnight'),
#  ('Jamaican Ministry of Local Government, Community Development & Sport',
#   'Jamaican Ministry of Local Government, Community Development & Sport'),
#  ('Jamaican Ministry of Tourism and Sports',
#   'Jamaican Ministry of Tourism and Sports'),
#  ('Jamaican Monk (Composition)', 'Jamaican Monk (Composition)'),
#  ('Jamaican Monk (Musical Recording)', 'Jamaican Monk (Musical Recording)'),
#  ('m.0k_hh5h', 'Jamaican Monk'),
#  ('m.0m6506q', 'Jamaican Monk'),
#  ('m.0skydw4', 'Jamaican Monk'),
#  ('Jamaican Monkey Man (Multi-Part Musical Release)',
#   'Jamaican Monkey Man (Multi-Part Musical Release)'),
#  ('Jamaican Monkey Man (Musical Album)',
#   'Jamaican Monkey Man (Musical Album)'),
#  ('Jamaican Mule (Canonical Version)', 'Jamaican Mule (Canonical Version)'),
#  ('m.0sjhtkz', 'Jamaican Mule'),
#  ('Jamaican Night', 'Jamaican Night'),
#  ('m.0m0v0yg', 'Jamaican Night'),
#  ('Jamaican Nightingale', 'Jamaican Nightingale'),
#  ('Jamaican Nights (Musical Recording)',
#   'Jamaican Nights (Musical Recording)'),
#  ('m.0lwnv46', 'Jamaican Nights'),
#  ('Jamaican Noel (Musical Recording) #1',
#   'Jamaican Noel (Musical Recording) #1'),
#  ('Jamaican Noel (Musical Recording) #2',
#   'Jamaican Noel (Musical Recording) #2'),
#  ('m.0ljc7dv', 'Jamaican Noel'),
#  ('m.0m_7kl3', 'Jamaican Noel'),
#  ('Jamaican Oriole', 'Jamaican Oriole'),
#  ('Jamaican Owl', 'Jamaican Owl'),
#  ('Jamaican People (Canonical Version)',
#   'Jamaican People (Canonical Version)'),
#  ('m.0kt6gts', 'Jamaican People'),
#  ('Jamaican Petrel', 'Jamaican Petrel'),
#  ('Jamaican Pewee', 'Jamaican Pewee'),
#  ('Jamaican Place (Musical Recording)', 'Jamaican Place (Musical Recording)'),
#  ('m.0ldgp04', 'Jamaican Place'),
#  ('m.0mbjg03', 'Jamaican Place'),
#  ('Jamaican Police (Canonical Version)',
#   'Jamaican Police (Canonical Version)'),
#  ('m.0ls5cx8', 'Jamaican Police'),
#  ('Jamaican Poorwill', 'Jamaican Poorwill'),
#  ('Jamaican Praise Medley', 'Jamaican Praise Medley'),
#  ('m.0mnqr0x', 'Jamaican Praise Medley'),
#  ('Jamaican Proverb (Musical Recording) #1',
#   'Jamaican Proverb (Musical Recording) #1'),
#  ('Jamaican Proverb (Musical Recording) #2',
#   'Jamaican Proverb (Musical Recording) #2'),
#  ('m.0ktm6gd', 'Jamaican Proverb'),
#  ('m.0lv_4l2', 'Jamaican Proverb'),
#  ('m.0m5kvv1', 'Jamaican Proverb'),
#  ('Jamaican Radio Edit (Canonical Version)',
#   'Jamaican Radio Edit (Canonical Version)'),
#  ('m.0lw2ms3', 'Jamaican Radio Edit'),
#  ('Jamaican Radio Obituary', 'Jamaican Radio Obituary'),
#  ('m.0knjndc', 'Jamaican Radio Obituary'),
#  ('Jamaican Recordings (Musical Album)',
#   'Jamaican Recordings (Musical Album)'),
#  ('Jamaican Red Macaw', 'Jamaican Red Macaw'),
#  ('Jamaican Rhumba', 'Jamaican Rhumba'),
#  ('Jamaican Rumba (Musical Recording) #13',
#   'Jamaican Rumba (Musical Recording) #13'),
#  ('Jamaican Rumba (Composition)', 'Jamaican Rumba (Composition)'),
#  ('Jamaican Rhumba (Canonical Version)',
#   'Jamaican Rhumba (Canonical Version)'),
#  ('Jamaican Rhumba (Musical Recording) #1',
#   'Jamaican Rhumba (Musical Recording) #1'),
#  ('Jamaican Rhumba (Musical Recording) #2',
#   'Jamaican Rhumba (Musical Recording) #2'),
#  ('Jamaican Rhumba (Musical Recording) #3',
#   'Jamaican Rhumba (Musical Recording) #3'),
#  ('m.0kldzcr', 'Jamaican Rhumba'),
#  ('m.0l25gcr', 'Jamaican Rhumba'),
#  ('m.0mq2rws', 'Jamaican Rhumba'),
#  ('m.0mr94mg', 'Jamaican Rhumba'),
#  ('m.0yb2sck', 'Jamaican Rhumba'),
#  ('Jamaican Robot (Musical Recording)', 'Jamaican Robot (Musical Recording)'),
#  ('m.0m8vw_r', 'Jamaican Robot'),
#  ('Jamaican Rock (Composition)', 'Jamaican Rock (Composition)'),
#  ('Jamaican Rock (Musical Recording)', 'Jamaican Rock (Musical Recording)'),
#  ('m.0lwmrcz', 'Jamaican Rock'),
#  ('m.0mff37v', 'Jamaican Rock'),
#  ('m.0mlcj6p', 'Jamaican Rock'),
#  ('m.0mncqr3', 'Jamaican Rock'),
#  ('Jamaican Rock Steady Party (Musical Album)',
#   'Jamaican Rock Steady Party (Musical Album)'),
#  ('Jamaican Roots (Musical Album)', 'Jamaican Roots (Musical Album)'),
#  ('Jamaican Rum (Canonical Version) #3',
#   'Jamaican Rum (Canonical Version) #3'),
#  ('Jamaican Rum (Canonical Version) #4',
#   'Jamaican Rum (Canonical Version) #4'),
#  ('Jamaican Rum (Canonical Version) #5',
#   'Jamaican Rum (Canonical Version) #5'),
#  ('Jamaican Rum (Musical Recording) #1',
#   'Jamaican Rum (Musical Recording) #1'),
#  ('Jamaican Rum (Musical Recording) #2',
#   'Jamaican Rum (Musical Recording) #2'),
#  ('m.0_djfv6', 'Jamaican Rum'),
#  ('m.0l8hkk5', 'Jamaican Rum'),
#  ('m.0lnrr7j', 'Jamaican Rum'),
#  ('m.0m45rnf', 'Jamaican Rum'),
#  ('m.0m7tvjb', 'Jamaican Rum'),
#  ('m.0yb7rks', 'Jamaican Rum'),
#  ('Jamaican Rum Rhumba (Musical Recording)',
#   'Jamaican Rum Rhumba (Musical Recording)'),
#  ('m.0l995jp', 'Jamaican Rum Rhumba'),
#  ('m.0mjr7vs', 'Jamaican Rum Rhumba'),
#  ('Jamaican Rum Rhumba (take two) (Musical Recording)',
#   'Jamaican Rum Rhumba (take two) (Musical Recording)'),
# ...
#  ('King of Salem (Jamaican version) (Musical Recording)',
#   'King of Salem (Jamaican version) (Musical Recording)'),
#  ('m.0mf2xkw', 'King of Salem (Jamaican version)'),
#  ('Know Love (extended Jamaican mix)', 'Know Love (extended Jamaican mix)'),
#  ('L-L-Lies (Jamaican pop mix) (Musical Recording)',
#   'L-L-Lies (Jamaican pop mix) (Musical Recording)'),
#  ('m.0kzv033', 'L-L-Lies (Jamaican pop mix)'),
#  ('La Jamaicana (Musical Recording)', 'La Jamaicana (Musical Recording)'),
#  ('m.0lclgph', 'La Jamaicana'),
#  ('Language in exile : three hundred years of Jamaican Creole',
#   'Language in exile : three hundred years of Jamaican Creole'),
#  ('Let Your Yeah Be Yeah (Jamaican mix) (Musical Recording)',
#   'Let Your Yeah Be Yeah (Jamaican mix) (Musical Recording)'),
#  ('m.0x8_v4f', 'Let Your Yeah Be Yeah (Jamaican mix)'),
#  ("Let's Play Ring Jamaican Style (Musical Recording)",
#   "Let's Play Ring Jamaican Style (Musical Recording)"),
#  ('m.0kl5j8v', "Let's Play Ring Jamaican Style"),
#  ('London Jamaican', 'London Jamaican'),
#  ('London Jamaican: language systems in interaction',
#   'London Jamaican: language systems in interaction'),
#  ('Love Forever: The Classic Jamaican Recordings (Musical Album)',
#   'Love Forever: The Classic Jamaican Recordings (Musical Album)'),
#  ('Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Musical Album)',
#   'Love Is All I Had : A Tribute to the Queen of Jamaican Soul (Musical Album)'),
#  ('Love of the Common People (Jamaican mix) (Musical Recording)',
#   'Love of the Common People (Jamaican mix) (Musical Recording)'),
#  ('m.0x8rw7m', 'Love of the Common People (Jamaican mix)'),
#  ('Mastery, tyranny, and desire : Thomas Thistlewood and his slaves in the Anglo-Jamaican world',
#   'Mastery, tyranny, and desire : Thomas Thistlewood and his slaves in the Anglo-Jamaican world'),
#  ('Mathematics Teaching and Learning for Jamaican Immigrants in New York City Public Schools: Relationships to Jamaican Classroom Practice',
#   'Mathematics Teaching and Learning for Jamaican Immigrants in New York City Public Schools: Relationships to Jamaican Classroom Practice'),
#  ('Meet the Jamaicans', 'Meet the Jamaicans'),
#  ('Mellow Meed (Jamaican Soul mix) (Musical Recording)',
#   'Mellow Meed (Jamaican Soul mix) (Musical Recording)'),
#  ('m.0ly8v5h', 'Mellow Meed (Jamaican Soul mix)'),
#  ('Montego Bay - Jamaican Persuasion (Musical Album)',
#   'Montego Bay - Jamaican Persuasion (Musical Album)'),
#  ('Mr. Bojangles (Jamaican mix) (Musical Recording)',
#   'Mr. Bojangles (Jamaican mix) (Musical Recording)'),
#  ('m.0ly3s9n', 'Mr. Bojangles (Jamaican mix)'),
#  ('My Jamaican Guy (Musical Recording) #4',
#   'My Jamaican Guy (Musical Recording) #4'),
#  ('My Jamaican Guy', 'My Jamaican Guy'),
#  ('My Jamaican Collie (Musical Recording) #1',
#   'My Jamaican Collie (Musical Recording) #1'),
#  ('My Jamaican Collie (Musical Recording) #2',
#   'My Jamaican Collie (Musical Recording) #2'),
#  ('My Jamaican Collie (Musical Recording) #3',
#   'My Jamaican Collie (Musical Recording) #3'),
#  ('m.0l9tj4n', 'My Jamaican Collie'),
#  ('m.0lndbkk', 'My Jamaican Collie'),
#  ('m.0m56n9l', 'My Jamaican Collie'),
#  ('m.0ms6yl9', 'My Jamaican Collie'),
#  ('m.0qgnvyw', 'My Jamaican Collie'),
#  ('My Jamaican Girl (Musical Recording) #1',
#   'My Jamaican Girl (Musical Recording) #1'),
#  ('My Jamaican Girl (Musical Recording) #2',
#   'My Jamaican Girl (Musical Recording) #2'),
#  ('My Jamaican Girl (Musical Recording) #3',
#   'My Jamaican Girl (Musical Recording) #3'),
#  ('My Jamaican Girl (Musical Recording) #4',
#   'My Jamaican Girl (Musical Recording) #4'),
#  ('My Jamaican Girl (Musical Recording) #5',
#   'My Jamaican Girl (Musical Recording) #5'),
#  ('My Jamaican Girl (Musical Recording) #6',
#   'My Jamaican Girl (Musical Recording) #6'),
#  ('m.0kkyb_6', 'My Jamaican Girl'),
#  ('m.0kvzprt', 'My Jamaican Girl'),
#  ('m.0lt0v28', 'My Jamaican Girl'),
#  ('m.0lz8bjz', 'My Jamaican Girl'),
#  ('m.0m56qfr', 'My Jamaican Girl'),
#  ('m.0m88q_q', 'My Jamaican Girl'),
#  ('m.0mdchj0', 'My Jamaican Girl'),
#  ('m.0mq81gz', 'My Jamaican Girl'),
#  ('m.0rllmb9', 'My Jamaican Girl'),
#  ('My Jamaican Guy (12" version) (Musical Recording) #1',
#   'My Jamaican Guy (12" version) (Musical Recording) #1'),
#  ('My Jamaican Guy (12" version) (Musical Recording) #2',
#   'My Jamaican Guy (12" version) (Musical Recording) #2'),
#  ('m.0l3fj4x', 'My Jamaican Guy (12" version)'),
#  ('m.0l5jm54', 'My Jamaican Guy (12" version)'),
#  ('m.0mj6ft0', 'My Jamaican Guy (12" version)'),
#  ('m.0mq0x3l', 'My Jamaican Guy (12" version)'),
#  ('m.0rr2mtp', 'My Jamaican Guy (12" version)'),
#  ('m.0rswzs1', 'My Jamaican Guy (12" version)'),
#  ('m.0rtkzym', 'My Jamaican Guy (12" version)'),
#  ('My Jamaican Guy (12") (Musical Recording)',
#   'My Jamaican Guy (12") (Musical Recording)'),
#  ('m.0n2y6zj', 'My Jamaican Guy (12")'),
#  ('My Jamaican Guy (Musical Recording) #1',
#   'My Jamaican Guy (Musical Recording) #1'),
#  ('My Jamaican Guy (Musical Recording) #2',
#   'My Jamaican Guy (Musical Recording) #2'),
#  ('My Jamaican Guy (Musical Recording) #3',
#   'My Jamaican Guy (Musical Recording) #3'),
#  ('My Jamaican Guy (Musical Recording) #5',
#   'My Jamaican Guy (Musical Recording) #5'),
#  ('My Jamaican Guy (Musical Recording) #6',
#   'My Jamaican Guy (Musical Recording) #6'),
#  ('My Jamaican Guy (Musical Recording) #7',
#   'My Jamaican Guy (Musical Recording) #7'),
#  ('My Jamaican Guy (Musical Recording) #8',
#   'My Jamaican Guy (Musical Recording) #8'),
#  ('My Jamaican Guy (Musical Recording) #9',
#   'My Jamaican Guy (Musical Recording) #9'),
#  ('My Jamaican Guy (feat. Bounty Killer) (Musical Recording)',
#   'My Jamaican Guy (feat. Bounty Killer) (Musical Recording)'),
#  ('m.0kksvkz', 'My Jamaican Guy (feat. Bounty Killer)'),
#  ('m.0_hvrxv', 'My Jamaican Guy'),
#  ('m.0l76t_z', 'My Jamaican Guy'),
#  ('m.0l9dfr5', 'My Jamaican Guy'),
#  ('m.0lk15db', 'My Jamaican Guy'),
#  ('m.0lvnv34', 'My Jamaican Guy'),
#  ('m.0m34rv5', 'My Jamaican Guy'),
#  ('m.0mg322g', 'My Jamaican Guy'),
#  ('m.0mlm5hl', 'My Jamaican Guy'),
#  ('m.0mnbrvm', 'My Jamaican Guy'),
#  ('m.0mp4bgf', 'My Jamaican Guy'),
#  ('m.0mps8m1', 'My Jamaican Guy'),
#  ('m.0mq0xm6', 'My Jamaican Guy'),
#  ('m.0mqg02t', 'My Jamaican Guy'),
#  ('m.0mw1tqm', 'My Jamaican Guy'),
#  ('m.0n2g55h', 'My Jamaican Guy'),
#  ('m.0qk8g2g', 'My Jamaican Guy'),
#  ('m.0rr3v2v', 'My Jamaican Guy'),
#  ('m.0v349d3', 'My Jamaican Guy'),
#  ('My mother who is me : life stories from Jamaican women in New York',
#   'My mother who is me : life stories from Jamaican women in New York'),
#  ('Nacao Jamaicana (Canonical Version)',
#   'Nacao Jamaicana (Canonical Version)'),
#  ('m.0kt3nnq', 'Nacao Jamaicana'),
#  ('Nice Jamaican Line (Musical Recording)',
#   'Nice Jamaican Line (Musical Recording)'),
#  ('m.0lzfnw1', 'Nice Jamaican Line'),
#  ('m.0mf7rdc', 'Nice Jamaican Line'),
#  ('Nice Time (alternate Jamaican Soul mix) (Musical Recording)',
#   'Nice Time (alternate Jamaican Soul mix) (Musical Recording)'),
#  ('m.0m4rrs_', 'Nice Time (alternate Jamaican Soul mix)'),
#  ('No bond but the law : punishment, race, and gender in Jamaican state formation, 1780-1870',
#   'No bond but the law : punishment, race, and gender in Jamaican state formation, 1780-1870'),
#  ('Noise (Jamaican edit) (Musical Recording)',
#   'Noise (Jamaican edit) (Musical Recording)'),
#  ('m.0x5506v', 'Noise (Jamaican edit)'),
#  ('Norman (extended Jamaican mix)', 'Norman (extended Jamaican mix)'),
#  ('Notes on Jamaican ethnobotany', 'Notes on Jamaican ethnobotany'),
#  ("Oh Lord I've Got to Get There (Jamaican mix) (Musical Recording)",
#   "Oh Lord I've Got to Get There (Jamaican mix) (Musical Recording)"),
#  ('m.0m4rs8r', "Oh Lord I've Got to Get There (Jamaican mix)"),
#  ('One blood : the Jamaican body', 'One blood : the Jamaican body'),
#  ('Original Cool Jamaican Ska (Musical Album)',
#   'Original Cool Jamaican Ska (Musical Album)'),
#  ('Ou Jamaican National Heroes (Musical Recording)',
#   'Ou Jamaican National Heroes (Musical Recording)'),
#  ('Our Jamaican National Heroes (Musical Recording)',
#   'Our Jamaican National Heroes (Musical Recording)'),
#  ('m.0lgtcsv', 'Ou Jamaican National Heroes'),
#  ('m.0mx69lt', 'Our Jamaican National Heroes'),
#  ('m.0spbnkf', 'Our Jamaican National Heroes'),
#  ('The Jamaican Maroons', 'The Jamaican Maroons'),
#  ('Party Time (extended Jamaican mix) (Musical Recording)',
#   'Party Time (extended Jamaican mix) (Musical Recording)'),
#  ('m.0zpmyy7', 'Party Time (extended Jamaican mix)'),
#  ("Pearl's Delicious Jamaican Dishes", "Pearl's Delicious Jamaican Dishes"),
#  ('Portraits of Jamaican Music', 'Portraits of Jamaican Music'),
#  ('Princess: A Sausage Party, Auditions to Utilize Ladies & A Big Jamaican Jerk',
#   'Princess: A Sausage Party, Auditions to Utilize Ladies & A Big Jamaican Jerk'),
#  ("Real Cool: The Jamaican King of the Saxophone '66-'77 (Musical Album)",
#   "Real Cool: The Jamaican King of the Saxophone '66-'77 (Musical Album)"),
#  ('Real Jamaican (Canonical Version)', 'Real Jamaican (Canonical Version)'),
#  ('Real Jamaican (feat. Mykal Roze) (Musical Recording)',
#   'Real Jamaican (feat. Mykal Roze) (Musical Recording)'),
#  ('m.0mk9m98', 'Real Jamaican (feat. Mykal Roze)'),
#  ('m.0ltg0_k', 'Real Jamaican'),
#  ('Reggae : the story of Jamaican music',
#   'Reggae : the story of Jamaican music'),
#  ('Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Musical Album)',
#   'Reggae Golden Jubilee: Origins of Jamaican Music - 50th Anniversary (Musical Album)'),
#  ('Reggae Love Songs: 50 Jamaican Lovers Classics (Musical Album)',
#   'Reggae Love Songs: 50 Jamaican Lovers Classics (Musical Album)'),
#  ('Reggae explosion : the story of Jamaican music',
#   'Reggae explosion : the story of Jamaican music'),
#  ('Reggae on Broadway (Jamaican mix) (Musical Recording)',
#   'Reggae on Broadway (Jamaican mix) (Musical Recording)'),
#  ('m.0m4rs6k', 'Reggae on Broadway (Jamaican mix)'),
#  ('Renewing democracy into the millennium : the Jamaican experience in perpective',
#   'Renewing democracy into the millennium : the Jamaican experience in perpective'),
#  ('Respect to Jamaican Dons (Musical Recording)',
#   'Respect to Jamaican Dons (Musical Recording)'),
#  ('m.0mkm_9x', 'Respect to Jamaican Dons'),
#  ('Responses of Jamaican and American deaf groups to stigma',
#   'Responses of Jamaican and American deaf groups to stigma'),
#  ('Responses of Jamaican and American deaf groups to stigma : a critical interpretive approach',
#   'Responses of Jamaican and American deaf groups to stigma : a critical interpretive approach'),
#  ('Rock to the Rock (original Jamaican Soul mix) (Musical Recording)',
#   'Rock to the Rock (original Jamaican Soul mix) (Musical Recording)'),
#  ('m.0m4rrr0', 'Rock to the Rock (original Jamaican Soul mix)'),
#  ('Rocking Steady (original Jamaican Soul mix) (Musical Recording)',
#   'Rocking Steady (original Jamaican Soul mix) (Musical Recording)'),
#  ('m.0ly8v9k', 'Rocking Steady (original Jamaican Soul mix)'),
#  ('The Jamaican Shower Posse', 'The Jamaican Shower Posse'),
#  ('Roots & Urban Culture: Una muestra del legado jamaicano (Musical Album)',
#   'Roots & Urban Culture: Una muestra del legado jamaicano (Musical Album)'),
#  ('Roots Reggae: The Classic Jamaican Albums (Musical Album)',
#   'Roots Reggae: The Classic Jamaican Albums (Musical Album)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 1: The Sensational Maytals)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 1: The Sensational Maytals)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 2: Sweet and Dandy)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 2: Sweet and Dandy)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 3: Monkey Man)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 3: Monkey Man)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 4: The Maytals Greatest Hits)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 4: The Maytals Greatest Hits)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 5: Slatyam Stoot)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 5: Slatyam Stoot)'),
#  ('Roots Reggae: The Classic Jamaican Albums (disc 6: Roots Reggae)',
#   'Roots Reggae: The Classic Jamaican Albums (disc 6: Roots Reggae)'),
#  ('Roots of Jamaican culture', 'Roots of Jamaican culture'),
#  ('Roots of Jamaican culture (Book Edition)',
#   'Roots of Jamaican culture (Book Edition)'),
#  ('Rosenś speak Jamaican (Book Edition)',
#   'Rosenś speak Jamaican (Book Edition)'),
#  ('Rosenś speak Jamaican (Book)', 'Rosenś speak Jamaican (Book)'),
#  ('Rude Boy Jamaican (Musical Recording) #1',
#   'Rude Boy Jamaican (Musical Recording) #1'),
#  ('Rude Boy Jamaican (Musical Recording) #2',
#   'Rude Boy Jamaican (Musical Recording) #2'),
#  ('m.0ll9128', 'Rude Boy Jamaican'),
#  ('m.0ly4bmb', 'Rude Boy Jamaican'),
#  ('Run Tings (100% Jamaican dub plates) (Musical Album)',
#   'Run Tings (100% Jamaican dub plates) (Musical Album)'),
#  ('Rural-urban migration and the Jamaican child',
#   'Rural-urban migration and the Jamaican child'),
#  ('Scottish Jamaican', 'Scottish Jamaican'),
#  ('Secret Heaven (Jamaican Heaven mix) (Musical Recording)',
#   'Secret Heaven (Jamaican Heaven mix) (Musical Recording)'),
#  ('m.0kqv2f4', 'Secret Heaven (Jamaican Heaven mix)'),
#  ('Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book Edition)',
#   'Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book Edition)'),
#  ('Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book)',
#   'Semiproletarianization and the structure of  socioeconomic and political relations in a Jamaican slum (Book)'),
#  ('Sha La La I Need You (Jamaican mix) (Canonical Version)',
#   'Sha La La I Need You (Jamaican mix) (Canonical Version)'),
#  ('m.0y1hhvs', 'Sha La La I Need You (Jamaican mix)'),
#  ('Shock Out Jamaican Style (Musical Recording)',
#   'Shock Out Jamaican Style (Musical Recording)'),
#  ('m.0lrm5b_', 'Shock Out Jamaican Style'),
#  ('Six great Jamaicans', 'Six great Jamaicans'),
#  ('Ska Boogie: Jamaican R&B, the Dawn of Ska (Musical Album)',
#   'Ska Boogie: Jamaican R&B, the Dawn of Ska (Musical Album)'),
#  ('Slaves and missionaries : the disintegration of Jamaican slave society, 1787-1834',
#   'Slaves and missionaries : the disintegration of Jamaican slave society, 1787-1834'),
#  ('Sled Shred featuring the Jamaican bobsled team (Sports Video Game)',
#   'Sled Shred featuring the Jamaican bobsled team (Sports Video Game)'),
#  ('Sled Shred featuring the Jamaican bobsled team (Video Game Version)',
#   'Sled Shred featuring the Jamaican bobsled team (Video Game Version)'),
#  ('Slum Dogz Vs. Pimento Jamaican Kitchen',
#   'Slum Dogz Vs. Pimento Jamaican Kitchen'),
#  ('Snoop Dogg: The Jamaican Episode', 'Snoop Dogg: The Jamaican Episode'),
#  ('Social change and social mobility in a Jamaican rural community',
#   'Social change and social mobility in a Jamaican rural community'),
#  ('Soon come : Jamaican spirituality, Jamaican poetics',
#   'Soon come : Jamaican spirituality, Jamaican poetics'),
#  ('Soul Revolutionaries: The Early Jamaican Albums (Multi-Part Musical Release)',
#   'Soul Revolutionaries: The Early Jamaican Albums (Multi-Part Musical Release)'),
#  ('Soul Revolutionaries: The Early Jamaican Albums (Musical Album)',
#   'Soul Revolutionaries: The Early Jamaican Albums (Musical Album)'),
#  ('Soundsystem: The Story of Jamaican Music (Musical Album)',
#   'Soundsystem: The Story of Jamaican Music (Musical Album)'),
#  ('Sources of Jamaican history, 1655-1838',
#   'Sources of Jamaican history, 1655-1838'),
#  ('Sources of Jamaican history, 1655-1838 : a bibliographical survey with particular reference to manuscript sources',
#   'Sources of Jamaican history, 1655-1838 : a bibliographical survey with particular reference to manuscript sources'),
#  ('Standing Tall: Affirmations of the Jamaican Male',
#   'Standing Tall: Affirmations of the Jamaican Male'),
#  ('Stoned Out of My Mind (Jamaican mix) (Musical Recording)',
#   'Stoned Out of My Mind (Jamaican mix) (Musical Recording)'),
#  ('m.0ly3s9w', 'Stoned Out of My Mind (Jamaican mix)'),
#  ...]

# %%
print(candidates1)
# Out:
# [('m.0kt6gts', 'Jamaican People'), ('Jamaican Petrel', 'Jamaican Petrel')]

# %%
for rank, (start_mid, start_label) in enumerate(final_candidates, 1):
    print("\n" + "=" * 80)
    print(f"Candidate #{rank}: {start_mid}  «{start_label}»")
    print(f"Hops (target): {predicted_hops}")

    start = start_mid
    frontier = { start }
    paths_by_end = { start: [tuple()] }
    all_paths = []

    for depth in range(1, predicted_hops + 1):
        if not frontier:
            print(f"[INFO] Depth {depth}: empty frontier, stop.", file=sys.stderr)
            break

        print(f"[INFO] Depth {depth}: frontier={len(frontier)}", file=sys.stderr)

        # Stream file, collect only edges whose subject is in current frontier
        neighbors = defaultdict(list)
        kept_counts = defaultdict(int)

        for s, p, o in iter_facts(facts_file):
            # Extract entity ID from subject
            s_id, s_name = extract_entity_info(s)
            if s_id not in frontier:
                continue
                
            # Skip noisy predicates
            skip = False
            for pref in SKIP_PREDICATES_PREFIXES:
                if p.startswith(pref):
                    skip = True
                    break
            if skip:
                continue
            
            # Skip literal values and some system predicates
            if (o.startswith('"') or o.startswith('<http') or 
                p in ['is-a', 'Length', 'Track #']):
                continue

            if kept_counts[s_id] < MAX_EDGES_PER_NODE_PER_DEPTH:
                # Extract object ID
                o_id, o_name = extract_entity_info(o)
                neighbors[s_id].append((p, o_id))
                kept_counts[s_id] += 1

        # Extend paths by one hop
        if len(frontier) > MAX_FRONTIER_NODES_PER_DEPTH:
            frontier = set(list(frontier)[:MAX_FRONTIER_NODES_PER_DEPTH])

        next_paths_by_end = defaultdict(list)
        total_paths_this_depth = 0

        for node in frontier:
            base_paths = paths_by_end.get(node, [])
            if not base_paths:
                continue
            outs = neighbors.get(node, [])
            if not outs:
                continue

            for (p, o) in outs:
                for base in base_paths:
                    new_seq = base + (p,)
                    next_paths_by_end[o].append(new_seq)
                    all_paths.append((new_seq, o))
                    total_paths_this_depth += 1
                    if total_paths_this_depth >= MAX_PATHS_PER_DEPTH:
                        break
                if total_paths_this_depth >= MAX_PATHS_PER_DEPTH:
                    break
            if total_paths_this_depth >= MAX_PATHS_PER_DEPTH:
                break

        # Build next frontier with cap
        next_frontier = set()
        for o in next_paths_by_end.keys():
            if len(next_frontier) >= MAX_FRONTIER_NODES_PER_DEPTH:
                break
            next_frontier.add(o)

        # keep only paths to nodes we actually keep in frontier
        next_paths_by_end = { n: next_paths_by_end[n] for n in next_frontier }

        print(f"[INFO] Depth {depth}: paths_kept={total_paths_this_depth}, next_frontier={len(next_frontier)}", file=sys.stderr)

        frontier = next_frontier
        paths_by_end = next_paths_by_end

    # Output Sample
    print(f"Total paths (≤ {predicted_hops} hops): {len(all_paths)}")
    to_show = all_paths if PRINT_SAMPLE_LIMIT is None else all_paths[:PRINT_SAMPLE_LIMIT]
    for i, (seq, end_node) in enumerate(to_show, 1):
        print(f"[{i:04d}] {fmt_path(seq)}   =>   {end_node}")
    if PRINT_SAMPLE_LIMIT is not None and len(all_paths) > PRINT_SAMPLE_LIMIT:
        print(f"... (showing first {PRINT_SAMPLE_LIMIT} of {len(all_paths)} paths)")

print("\n[Done]", file=sys.stderr)
# Out:
# ================================================================================
# Candidate #1: m.0lsyw5q  «Distinguished Jamaican English»
# Hops (target): 1
# [INFO] Depth 1: frontier=1
# [INFO] Depth 1: paths_kept=2, next_frontier=2
# [INFO] Depth 1: frontier=1
# Total paths (≤ 1 hops): 2
# [0001] Recording   =>   Distinguished Jamaican English (Musical Recording)
# [0002] Release   =>   Something Wicked This Way Comes (Consumer product) #85
#
# ================================================================================
# Candidate #2: How to speak Jamaican? (Book)  «How to speak Jamaican? (Book)»
# Hops (target): 1
# [INFO] Depth 1: paths_kept=1, next_frontier=1
# [INFO] Depth 1: frontier=1
# Total paths (≤ 1 hops): 1
# [0001] Author   =>   Ken Maxwell (Author)
#
# ================================================================================
# Candidate #3: Jamaican Creole English Language  «Jamaican Creole English Language»
# Hops (target): 1
# [INFO] Depth 1: paths_kept=5, next_frontier=4
# [INFO] Depth 1: frontier=1
# Total paths (≤ 1 hops): 5
# [0001] Language Family   =>   Creole language
# [0002] Language Family   =>   English-based creole languages
# [0003] Main Country   =>   Jamaica
# [0004] Region   =>   Americas
# [0005] Spoken in country   =>   Jamaica
#
# ================================================================================
# Candidate #4: Jamaican Creole  «Jamaican Creole»
# Hops (target): 1
# [INFO] Depth 1: paths_kept=3, next_frontier=3
# [INFO] Depth 1: frontier=1
# Total paths (≤ 1 hops): 3
# [0001] Author   =>   R. B. Le Page
# [0002] Subject   =>   Creole dialects
# [0003] Subject   =>   Slavery
#
# ================================================================================
# Candidate #5: Jamaican English  «Jamaican English»
# Hops (target): 1
# Total paths (≤ 1 hops): 1
# [0001] Spoken in country   =>   Jamaica
# [INFO] Depth 1: paths_kept=1, next_frontier=1
#
# [Done]

# %% [markdown]
# ## SQlite Database Approach

# %%
# graph_retriever.py
import sqlite3
from collections import deque

class GraphRetriever:
    def __init__(self, db_file):
        """
        Initializes the retriever by connecting to the pre-built SQLite database.
        """
        try:
            self.db_file = db_file
            self.con = sqlite3.connect(self.db_file)
        except sqlite3.OperationalError as e:
            print(f"Error connecting to database at '{db_file}': {e}")
            print("Please make sure you have run the 'preprocess_kg.py' script first.")
            raise

    def get_mid_for_name(self, name: str) -> str | None:
        """Looks up the MID for a given entity name."""
        cur = self.con.cursor()
        res = cur.execute("SELECT mid FROM mappings WHERE name = ?", (name,))
        result = res.fetchone()
        return result[0] if result else None

    def get_name_for_mid(self, mid: str) -> str | None:
        """Looks up the entity name for a given MID."""
        cur = self.con.cursor()
        res = cur.execute("SELECT name FROM mappings WHERE mid = ?", (mid,))
        result = res.fetchone()
        return result[0] if result else None

    def get_relations_from_entity(self, entity_subject: str) -> list[tuple[str, str]]:
        """
        Retrieves all outgoing (predicate, object) pairs for a given subject entity.
        This query is fast due to the index on the 'subject' column.
        """
        cur = self.con.cursor()
        res = cur.execute("SELECT predicate, object FROM graph WHERE subject = ?", (entity_subject,))
        return res.fetchall()

    def find_relation_links(self, start_entity_subject: str, max_depth: int) -> set[tuple]:
        """
        Performs a Breadth-First Search (BFS) to find all relation paths
        up to a certain depth. This is the 'Relation Retrieval' step.
        """
        if max_depth <= 0:
            return set()

        q = deque([(start_entity_subject, [])])
        found_relation_links = set()

        while q:
            current_subject, path = q.popleft()

            if len(path) >= max_depth:
                continue

            # This is a fast, indexed SQL query
            neighbors = self.get_relations_from_entity(current_subject)

            for predicate, obj in neighbors:
                new_path = path + [predicate]
                
                # Add the complete relation path as a tuple (to make it hashable)
                found_relation_links.add(tuple(new_path))
                
                q.append((obj, new_path))
                
        return found_relation_links

    def close(self):
        """Closes the database connection."""
        self.con.close()

# %%
print("Initializing GraphRetriever...")
db_file = "./freeb_db"  
retriever = GraphRetriever(db_file)

# Example
topic_mid = "m.03_r3"
start_entity_name = retriever.get_mid_for_name('Nick Cannon')
print(f"Looking up MID for 'Nick Cannon': {start_entity_name}")

if start_entity_name:
    print(f"Found name for MID '{topic_mid}': '{start_entity_name}'")
    
    predicted_hops = 2
    
    print(f"Starting BFS with max depth {predicted_hops}...")
    relation_links = retriever.find_relation_links(start_entity_name, predicted_hops)
    
    print(f"\nFound {len(relation_links)} unique relation links:")
    # Print some of the found links
    for i, link in enumerate(list(relation_links)):
        if i >= 15: break 
        print(f"  -> {' -> '.join(link)}")

else:
    print(f"Could not find a name for the MID '{topic_mid}' in the mappings table.")

# Clean up the connection
retriever.close()
print("\nRetriever closed.")
# Out:
# Initializing GraphRetriever...
# Looking up MID for 'Nick Cannon': None
# Could not find a name for the MID 'm.03_r3' in the mappings table.
#
# Retriever closed.

# %%
retriever = GraphRetriever(db_file)
    
relation_links = retriever.find_relation_links('Jamaica', 1)

print(f"\nFound {len(relation_links)} unique relation links:")
# Print some of the found links
for i, link in enumerate(list(relation_links)): 
    print(f"  -> {' -> '.join(link)}")

# Clean up the connection
retriever.close()
print("\nRetriever closed.")
# Out:
# Found 27 unique relation links:
#   -> Calling Code
#   -> FIPS Code
#   -> Time zone(s)
#   -> ISO Alpha 3
#   -> Olympics participated in
#   -> FIFA Code
#   -> ISO Short Name
#   -> Capital
#   -> Internet TLD
#   -> people/place_lived/location
#   -> Area
#   -> Official Language
#   -> Size of armed forces
#   -> Contained by
#   -> Nearby airport
#   -> Date founded
#   -> Currency Used
#   -> ISO Numeric
#   -> Member of
#   -> Form of Government
#   -> Multi-event tournament participated in
#   -> IOC Code
#   -> Net migration
#   -> ISO Alpha 2
#   -> is-a
#   -> Adjectival form
#   -> Population
#
# Retriever closed.

# %% [markdown]
# ## Finding relevent paths from database

# %%
import sqlite3
from sentence_transformers import SentenceTransformer, util


def get_name_for_mid(con: sqlite3.Connection, mid: str) -> str | None:
    cursor = con.cursor()
    res = cursor.execute("SELECT name FROM mappings WHERE mid = ?", (mid,))
    result = res.fetchone()
    return result[0] if result else None

def retrieve_all_links_from_db(con: sqlite3.Connection, start_entity: str, max_depth: int) -> set:
    found_links = set()
    cursor = con.cursor()
    # Queue stores tuples of (current_entity, current_path_of_relations)
    queue = [(start_entity, [])]
    # Keep track of entities visited at the current depth to avoid redundant DB calls in cycles
    visited_entities = {start_entity}

    while queue:
        current_entity, path = queue.pop(0)

        if len(path) >= max_depth:
            continue

        # This is the fast, indexed query to the database
        res = cursor.execute("SELECT predicate, object FROM graph WHERE subject = ?", (current_entity,))
        
        for predicate, obj in res.fetchall():
            new_path = path + [predicate]
            found_links.add(tuple(new_path))
            
            if obj not in visited_entities:
                queue.append((obj, new_path))
                visited_entities.add(obj)
    
    return found_links

def rank_links_by_similarity(question: str, links: set, model: SentenceTransformer) -> list:
    if not links:
        return []

    link_list = list(links)
    formatted_links = [" ".join(link).replace("_", " ").replace(".", " ") for link in link_list]

    question_embedding = model.encode(question, convert_to_tensor=True)
    link_embeddings = model.encode(formatted_links, convert_to_tensor=True)

    cosine_scores = util.cos_sim(question_embedding, link_embeddings)[0]

    scored_links = list(zip(link_list, cosine_scores.tolist()))
    scored_links.sort(key=lambda x: x[1], reverse=True)

    return scored_links

def get_final_answer_from_db(con: sqlite3.Connection, start_entity: str, relation_path: tuple) -> list:
    cursor = con.cursor()
    # For a simple 1-hop path, this is a direct query
    if len(relation_path) == 1:
        relation = relation_path[0]
        res = cursor.execute("SELECT object FROM graph WHERE subject = ? AND predicate = ?", (start_entity, relation))
        return [row[0] for row in res.fetchall()]
    else:
        # This would need to be expanded for multi-hop paths
        print("This simple script currently only finds answers for 1-hop paths.")
        return []

# %%
DB_FILE = "./freeb_db"

# setup with example
question = "what language is spoken by jamaican people?"
topic_mid = "m.03_r3" # The MID for Jamaica from the WebQSP dataset
hops = 1

print("Loading sentence embedding model...")
model = SentenceTransformer('all-MiniLM-L6-v2')

print(f"Connecting to database: {DB_FILE}")
db_connection = sqlite3.connect(DB_FILE)
print("-" * 30)

# Get starting entity 
print(f"Step 1: Finding canonical name for MID '{topic_mid}'...")
start_entity = 'Jamaica' # get_name_for_mid(db_connection, topic_mid)

if not start_entity:
    raise ValueError(f"Could not find a name for MID '{topic_mid}' in the database.")
print(f"Found start entity: '{start_entity}'")
print("-" * 30)

# retrieve all possible links
print(f"Step 2: Finding all {hops}-hop links from '{start_entity}'...")
all_possible_links = retrieve_all_links_from_db(db_connection, start_entity, hops)
print(f"Found {len(all_possible_links)} possible relations.")
print("-" * 30)

# link ranking
print("Step 3: Ranking links by similarity to the question...")
ranked_links = rank_links_by_similarity(question, all_possible_links, model)
print("Top 10 ranked relations:")
for link, score in ranked_links[:10]:
    print(f"- Score: {score:.4f}, Relation: {' -> '.join(link)}")
print("-" * 30)

# final answer, just for testing top output of ranking algorithm
print("Step 4: Getting the answer using the top-ranked relation...")
if ranked_links:
    top_relation_path = ranked_links[0][0]
    answers = get_final_answer_from_db(db_connection, start_entity, top_relation_path)
    
    print("\n--- FINAL ANSWER ---")
    print(f"Question: {question}")
    print(f"Most Relevant Relation: '{' -> '.join(top_relation_path)}'")
    print(f"Answer(s): {answers}")
else:
    print("Could not find a relevant answer.")
    
# --- F. CLEANUP ---
db_connection.close()
print("\nDatabase connection closed.")


#E5
# Out:
# Loading sentence embedding model...
# Connecting to database: ./freeb_db
# ------------------------------
# Step 1: Finding canonical name for MID 'm.03_r3'...
# Found start entity: 'Jamaica'
# ------------------------------
# Step 2: Finding all 1-hop links from 'Jamaica'...
# Found 27 possible relations.
# ------------------------------
# Step 3: Ranking links by similarity to the question...
# Top 10 ranked relations:
# - Score: 0.3855, Relation: Official Language
# - Score: 0.2844, Relation: people/place_lived/location
# - Score: 0.1843, Relation: Population
# - Score: 0.1612, Relation: Currency Used
# - Score: 0.1524, Relation: Olympics participated in
# - Score: 0.1154, Relation: Area
# - Score: 0.0999, Relation: is-a
# - Score: 0.0984, Relation: Contained by
# - Score: 0.0916, Relation: Time zone(s)
# - Score: 0.0788, Relation: Calling Code
# ------------------------------
# Step 4: Getting the answer using the top-ranked relation...
#
# --- FINAL ANSWER ---
# Question: what language is spoken by jamaican people?
# Most Relevant Relation: 'Official Language'
# Answer(s): ['Jamaican English']
#
# Database connection closed.

# %% [markdown]
# ## DB Creation

# %%
# preprocess_kg.py
import sqlite3
import os
from tqdm import tqdm
import re

# configurations
RAW_DATA_DIR = "freebase-easy-14-04-14/freebase-easy-14-04-14"
DB_FILE = "./freeb_db"

FACTS_FILE = os.path.join(RAW_DATA_DIR, "/run/media/sakhil/sakhil/IIIT H/ANLP/Project/freebase-easy-14-04-14/facts.txt")
LINKS_FILE = os.path.join(RAW_DATA_DIR, "/run/media/sakhil/sakhil/IIIT H/ANLP/Project/freebase-easy-14-04-14/freebase-links.txt")


# Delete the old DB file to ensure a fresh start
if os.path.exists(DB_FILE):
    print(f"Removing existing database at {DB_FILE}...")
    os.remove(DB_FILE)

# Connect to SQLite (this will create the file)
con = sqlite3.connect(DB_FILE)
cur = con.cursor()

print("--- Step 1: Processing Freebase Links File ---")

# Create a table for name <-> mid mappings
cur.execute("""
    CREATE TABLE mappings (
        name TEXT NOT NULL,
        mid TEXT NOT NULL
    );
""")
print("Created 'mappings' table.")

# Prepare for batch inserts
batch = []
batch_size = 100000

with open(LINKS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
    for line in tqdm(f, desc="Reading links file"):
        try:
            parts = line.strip().split('\t')
            if len(parts) >= 3 and parts[1] == 'freebase-entity':
                name = parts[0]
                # Regex to reliably extract the MID
                match = re.search(r'/ns/(m\..+)>', parts[2])
                if match:
                    mid = match.group(1)
                    batch.append((name, mid))
            
            if len(batch) >= batch_size:
                cur.executemany("INSERT INTO mappings VALUES(?, ?)", batch)
                batch = []
        except Exception:
            pass
# Insert any remaining records from the last batch
if batch:
    cur.executemany("INSERT INTO mappings VALUES(?, ?)", batch)

# Create indexes for fast lookups in both directions
print("Creating indexes on 'mappings' table...")
cur.execute("CREATE INDEX idx_map_name ON mappings (name);")
cur.execute("CREATE INDEX idx_map_mid ON mappings (mid);")
con.commit()
print("Finished processing links file.")

print("\n--- Step 2: Processing Facts File ---")

# Create the main table for the knowledge graph facts
cur.execute("""
    CREATE TABLE graph (
        subject TEXT NOT NULL,
        predicate TEXT NOT NULL,
        object TEXT NOT NULL
    );
""")
print("Created 'graph' table.")
batch = [] # Reset batch for the next file

with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
    for line in tqdm(f, desc="Reading facts file"):
        try:
            parts = line.strip().split('\t')
            if len(parts) >= 3:
                # The final part is often a '.', which we can ignore
                subject, predicate, obj = parts[0], parts[1], parts[2]
                batch.append((subject, predicate, obj))
            
            if len(batch) >= batch_size:
                cur.executemany("INSERT INTO graph VALUES(?, ?, ?)", batch)
                batch = []
        except Exception:
            pass

# Insert any remaining records
if batch:
    cur.executemany("INSERT INTO graph VALUES(?, ?, ?)", batch)

# Create an index on the 'subject' column for fast BFS lookups
print("Creating index on 'graph' table (this is the final, longest step)...")
cur.execute("CREATE INDEX idx_graph_subject ON graph (subject);")

# Commit all changes and close the connection
print("Committing final changes to the database...")
con.commit()
con.close()

print(f"\nPreprocessing complete! Your SQLite database is ready at '{DB_FILE}'.")
# Out:
# Removing existing database at ./freeb_db...
# --- Step 1: Processing Freebase Links File ---
# Created 'mappings' table.
# Reading links file: 0it [00:00, ?it/s]
# Reading links file: 21719311it [00:31, 694448.82it/s]
# Creating indexes on 'mappings' table...
# Finished processing links file.
#
# --- Step 2: Processing Facts File ---
# Created 'graph' table.
# Reading facts file: 241898031it [10:57, 367675.91it/s]
# Creating index on 'graph' table (this is the final, longest step)...
# Committing final changes to the database...
#
# Preprocessing complete! Your SQLite database is ready at './freeb_db'.

# %% [markdown]
# ## using Network X

# %%
# preprocess_kg_networkx.py
import networkx as nx
import os
import pickle
from tqdm import tqdm

# configurations
RAW_DATA_DIR = "/run/media/sakhil/sakhil/IIIT H/ANLP/Project/freebase-easy-14-04-14/"
OUT_DIR = "/run/media/sakhil/sakhil/IIIT H/ANLP/Project/NetworkXGraph/"

FACTS_FILE = os.path.join(RAW_DATA_DIR, "facts.txt")


os.makedirs(OUT_DIR, exist_ok=True)

print("--- Step 1: Building Mappings (Entity/Relation -> Integer ID) ---")
# This part is identical to the DGL version, as it's library-agnostic.
entity_map = {}
relation_map = {}

def add_to_map(item, item_map):
    if item not in item_map:
        item_map[item] = len(item_map)

# This will now read your actual large Facts.txt file
with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
    for line in tqdm(f, desc="Mapping entities and relations"):
        try:
            parts = line.strip().split('\t')
            if len(parts) >= 3:
                subject, predicate, obj = parts[0], parts[1], parts[2]
                add_to_map(subject, entity_map)
                add_to_map(predicate, relation_map)
                add_to_map(obj, entity_map)
        except Exception:
            pass

print(f"Found {len(entity_map)} unique entities and {len(relation_map)} unique relations.")

map_path = os.path.join(OUT_DIR, "mappings.pkl")
with open(map_path, 'wb') as f:
    pickle.dump({'entities': entity_map, 'relations': relation_map}, f)
print(f"Mappings saved to {map_path}")


print("\n--- Step 2: Building the NetworkX Graph ---")
# Use a MultiDiGraph to handle multiple different edges between two nodes
G = nx.MultiDiGraph()

with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
    for line in tqdm(f, desc="Creating graph edges"):
        try:
            parts = line.strip().split('\t')
            if len(parts) >= 3:
                subject, predicate, obj = parts[0], parts[1], parts[2]
                src_id = entity_map[subject]
                dest_id = entity_map[obj]
                
                # Add an edge with the relation name as an attribute
                G.add_edge(src_id, dest_id, relation=predicate)
        except Exception:
            pass

# Add all nodes to the graph, including those that might not be a source node
G.add_nodes_from(range(len(entity_map)))

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")

# Save the graph using Python's pickle module
graph_path = os.path.join(OUT_DIR, "kg_graph.gpickle")
with open(graph_path, 'wb') as f:
    pickle.dump(G, f)
print(f"NetworkX graph saved to {graph_path}")
print("\nPreprocessing with NetworkX is complete!")
# Out:
# --- Step 1: Building Mappings (Entity/Relation -> Integer ID) ---
# Mapping entities and relations: 173190144it [04:18, 670658.72it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 30
#      28 # This will now read your actual large Facts.txt file
#      29 with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
# ---> 30     for line in tqdm(f, desc="Mapping entities and relations"):
#      31         try:
#      32             parts = line.strip().split('\t')
#
# File /run/media/sakhil/sakhil/IIIT H/ANLP/Project/kg/lib64/python3.13/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1180 try:
#    1181     for obj in iterable:
# -> 1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#    1185         n += 1
#
# KeyboardInterrupt:

# %%
# graph_retriever_networkx.py
import networkx as nx
import os
import pickle
from collections import deque

class GraphRetrieverNX:
    def __init__(self, graph_dir="/run/media/sakhil/sakhil/IIIT H/ANLP/Project/NetworkXGraph/"):
        print("Loading NetworkX graph and mappings...")
        # Load the saved graph using Python's pickle module
        graph_path = os.path.join(graph_dir, "kg_graph.gpickle")
        with open(graph_path, 'rb') as f:
            self.graph = pickle.load(f)

        # Load the mappings
        map_path = os.path.join(graph_dir, "mappings.pkl")
        with open(map_path, 'rb') as f:
            mappings = pickle.load(f)
            self.entity_map = mappings['entities']
            # We don't need the relation map for retrieval, but we'll keep the rev_entity_map
        
        self.rev_entity_map = {v: k for k, v in self.entity_map.items()}
        print("NetworkX retriever initialized successfully.")

    def find_relation_links(self, start_entity_name: str, max_depth: int) -> set:
        """Performs a manual BFS to find all relation paths up to a max_depth."""
        if start_entity_name not in self.entity_map:
            print(f"Warning: Entity '{start_entity_name}' not found in graph.")
            return set()
            
        start_node_id = self.entity_map[start_entity_name]
        
        # A queue for BFS will store tuples of (node_id, current_path_of_relations)
        queue = deque([(start_node_id, [])])
        
        found_links = set()

        while queue:
            current_node, current_path = queue.popleft()
            
            # Stop exploring if we've reached the maximum depth
            if len(current_path) >= max_depth:
                continue
                
            # G.edges(node, data=True) gets all outgoing edges with their attributes
            for _, neighbor, edge_data in self.graph.edges(current_node, data=True):
                relation = edge_data['relation']
                
                # Create the new path by extending the current one
                new_path = current_path + [relation]
                
                # Add the new path (as a tuple) to our results
                found_links.add(tuple(new_path))
                
                # Add the neighbor and its new path to the queue for further exploration
                queue.append((neighbor, new_path))
                    
        return found_links


# example
if __name__ == '__main__':
    # This assumes you have run the preprocessing script first.
    retriever = GraphRetrieverNX()
    
    start_entity_name = "Nick Cannon"
    predicted_hops = 2
    
    print(f"Starting BFS from '{start_entity_name}' with depth {predicted_hops}...")
    relation_links = retriever.find_relation_links(start_entity_name, predicted_hops)
    
    print(f"\nFound {len(relation_links)} unique relation links:")
    for link in sorted(list(relation_links)): # Sorted for consistent output
        print(f"  -> {' -> '.join(link)}")
# Out:
# Loading NetworkX graph and mappings...
# NetworkX retriever initialized successfully.
# Starting BFS from 'Nick Cannon' with depth 2...
#
# Found 6 unique relation links:
#   -> acted_in
#   -> acted_in -> has_genre
#   -> has_spouse
#   -> has_spouse -> acted_in
#   -> produced
#   -> produced -> has_genre

# %% [markdown]
# ## Using Neo4j

# %%
import os
from neo4j import GraphDatabase
from tqdm import tqdm
import re

# configurations
RAW_DATA_DIR = "./freebase-easy-14-04-14"
FACTS_FILE = os.path.join(RAW_DATA_DIR, "facts.txt")
LINKS_FILE = os.path.join(RAW_DATA_DIR, "freebase-links.txt") # Added this back


# Neo4j connection details
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "kallind123" # The password you set in Neo4j Desktop

CHUNK_SIZE = 50000

class Neo4jDirectImporter:
    def __init__(self, uri, user, password):
        try:
            self.driver = GraphDatabase.driver(uri, auth=(user, password))
            self.driver.verify_connectivity()
            print("Successfully connected to Neo4j database.")
        except Exception as e:
            print(f"Failed to connect to Neo4j. Error: {e}")
            raise

    def close(self):
        self.driver.close()

    def setup_constraints(self):
        print("Setting up database constraints...")
        with self.driver.session() as session:
            # This constraint is CRITICAL for performance of the MERGE operation.
            query = "CREATE CONSTRAINT entity_unique_id IF NOT EXISTS FOR (n:Entity) REQUIRE n.entityId IS UNIQUE"
            session.run(query)
        print("Constraints are set.")
    
    def import_nodes_in_chunks(self):
        print("\n--- Pass 1: Importing Nodes ---")
        entities_seen_in_db = set()
        entities_to_add_chunk = set()

        with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
            for line in tqdm(f, desc="Scanning for and importing nodes"):
                try:
                    parts = line.strip().split('\t')
                    if len(parts) >= 3:
                        subject, _, obj = parts[0], parts[1], parts[2]
                        
                        if subject not in entities_seen_in_db:
                            entities_to_add_chunk.add(subject)
                        if obj not in entities_seen_in_db:
                            entities_to_add_chunk.add(obj)

                        if len(entities_to_add_chunk) >= CHUNK_SIZE:
                            self._write_node_chunk(entities_to_add_chunk)
                            entities_seen_in_db.update(entities_to_add_chunk)
                            entities_to_add_chunk.clear()
                except Exception:
                    pass
            
            # Write the final chunk if any entities are left
            if entities_to_add_chunk:
                self._write_node_chunk(entities_to_add_chunk)

    def _write_node_chunk(self, chunk):
        with self.driver.session() as session:
            query = """
            UNWIND $nodes AS node_data
            MERGE (e:Entity {entityId: node_data.id})
            ON CREATE SET e.name = node_data.name
            """
            # Create a list of dictionaries for the query parameter
            node_list = [{'id': name, 'name': name} for name in chunk]
            session.run(query, nodes=node_list)

    def import_relationships_in_chunks(self):
        print("\n--- Pass 2: Importing Relationships ---")
        relations_chunk = []

        with open(FACTS_FILE, 'r', encoding='utf-8', errors='ignore') as f:
            for line in tqdm(f, desc="Importing relationships"):
                try:
                    parts = line.strip().split('\t')
                    if len(parts) >= 3:
                        subject, predicate, obj = parts[0], parts[1], parts[2]
                        relations_chunk.append({'sub': subject, 'obj': obj, 'pred': predicate})

                        if len(relations_chunk) >= CHUNK_SIZE:
                            self._write_relationship_chunk(relations_chunk)
                            relations_chunk.clear()
                except Exception:
                    pass
            
            # Write the final chunk
            if relations_chunk:
                self._write_relationship_chunk(relations_chunk)

    def _write_relationship_chunk(self, chunk):
        with self.driver.session() as session:
            query = """
            UNWIND $rels AS rel
            MATCH (a:Entity {entityId: rel.sub})
            MATCH (b:Entity {entityId: rel.obj})
            CALL apoc.create.relationship(a, rel.pred, {}, b) YIELD rel as r
            RETURN count(r)
            """
            session.run(query, rels=chunk)

importer = Neo4jDirectImporter(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)

# 1. Set up constraints for performance
importer.setup_constraints()

# 2. Import all nodes
importer.import_nodes_in_chunks()

# 3. Import all relationships
importer.import_relationships_in_chunks()

print("\nData import complete!")

if 'importer' in locals() and importer.driver:
    importer.close()
    print("Database connection closed.")
# Out:
# Successfully connected to Neo4j database.
# Setting up database constraints...
# Constraints are set.
#
# --- Pass 1: Importing Nodes ---
# Scanning for and importing nodes: 194180080it [43:55, 81273.07it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
